# %%
'''!pip -q install "numpy<2.0" "scipy<1.11" "gensim==4.3.2" \
                tqdm pandas matplotlib scikit-learn spacy==3.7.4

# spaCy English model
# !python -m spacy download en_core_web_sm -qq
print("✅  All wheels installed — now click  Runtime ▸ Restart  .")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ✅  All wheels installed — now click  Runtime ▸ Restart  .

# %%
"""
Earnings-call LDA pipeline  (Chapter-15 style)
=============================================
• Split master transcript into quarterly calls
• spaCy lemmatise + stop/POS filter
• min_df / max_df vocab trimming
• Grid-search Gensim LDA (UMass coherence)
• Outputs:
    - call_topics.csv            (wide matrix)
    - call_topic_details.csv     (long per-call list, top-k topics)
"""
# ---------- imports -----------------------------
import re, datetime as dt, itertools, numpy as np, matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
from tqdm.auto import tqdm

import spacy, gensim
from gensim.corpora import Dictionary
from gensim.models import LdaModel, CoherenceModel

# ---------- user config -------------------------
SOURCE_FILE = Path("/content/EQIX_transcripts.txt")
CALL_DIR    = Path("/content/calls_split"); CALL_DIR.mkdir(exist_ok=True)
TOPIC_CSV   = Path("/content/call_topics.csv")
DETAIL_CSV  = Path("/content/call_topic_details.csv")

MIN_DF = 0.01     # keep tokens appearing in ≥1 % and ≤25 % docs
MAX_DF = 0.25
K_RANGE = range(5, 21)      # topic counts to test
TOPN_WORDS = 12
TOP_K_PER_CALL = 5          # strongest topics to record per call
MIN_PROB_TO_KEEP = 0.02

# ---------- split master transcript -------------
HDR = re.compile(r"^=+\s*(?P<year>\d{4})\s*Q(?P<qtr>[1-4])\s*\((?P<ts>[\d\- :]+)\)\s*=+", re.MULTILINE)
def split(path):
    txt = path.read_text(errors="ignore")
    meta, calls = [], {}
    hits = list(HDR.finditer(txt))
    for i, m in enumerate(hits):
        body = txt[m.end(): hits[i+1].start() if i+1<len(hits) else len(txt)].strip()
        cid  = f"{m['year']}-Q{m['qtr']}"
        (CALL_DIR/f"{cid}.txt").write_text(body)
        calls[cid] = body
        meta.append({"call_id":cid,
                     "timestamp":dt.datetime.fromisoformat(m['ts'].strip())})
    return meta, calls
meta, calls = split(SOURCE_FILE); print("Split →",len(meta),"calls")

# ---------- spaCy clean -------------------------
nlp = spacy.load("en_core_web_sm", disable=["ner","parser"])
for w in {"quarter","year","q&a","operator"}: nlp.vocab[w].is_stop=True

def tokens(doc):
    d=nlp(doc.lower())
    return [t.lemma_ for t in d if t.is_alpha and not t.is_stop and t.pos_ in {"NOUN","ADJ"}]

token_lists = [tokens(t) for t in tqdm(calls.values())]

# ---------- min_df / max_df vocab trim ----------
df = pd.Series(itertools.chain.from_iterable({w for w in s} for s in token_lists)).value_counts()
keep = df[(df>=MIN_DF*len(token_lists)) & (df<=MAX_DF*len(token_lists))].index
token_lists = [[w for w in doc if w in keep] for doc in token_lists]

dictionary  = Dictionary(token_lists)
corpus_bow  = [dictionary.doc2bow(t) for t in token_lists]
print("Vocabulary size:", len(dictionary))

# ---------- grid-search LDA --------------------
best_k,best_coh,best_lda=None,-np.inf,None
for k in K_RANGE:
    lda=LdaModel(corpus_bow, id2word=dictionary, num_topics=k,
                 passes=10, alpha="auto", random_state=42)
    coh=CoherenceModel(model=lda, corpus=corpus_bow,
                       coherence="u_mass").get_coherence()
    print(f"k={k:2d} → UMass {coh:.3f}")
    if coh>best_coh: best_k,best_coh,best_lda=k,coh,lda
lda = best_lda
print(f"\n✅  Best model: k={best_k}  (UMass={best_coh:.3f})")

# show topic keywords
for t in range(lda.num_topics):
    print(f"[T{t:02}] "," , ".join(w for w,_ in lda.show_topic(t, topn=TOPN_WORDS)))

# ---------- wide matrix per call ---------------
rows=[]
for meta_row,bow in zip(meta,corpus_bow):
    dist=lda.get_document_topics(bow, minimum_probability=0.0)
    rows.append({"call_id":meta_row["call_id"],
                 "timestamp":meta_row["timestamp"],
                 **{f"T{tid:02}":prob for tid,prob in dist}})
topic_df=pd.DataFrame(rows).sort_values("timestamp")
topic_df.to_csv(TOPIC_CSV,index=False,date_format="%Y-%m-%d %H:%M:%S")
print("Saved", TOPIC_CSV)

# ---------- long table: top-K topics per call ---
kw_cache={t:", ".join(w for w,_ in lda.show_topic(t, topn=10))
          for t in range(lda.num_topics)}
detail=[]
for (cid,ts),bow in zip(meta,corpus_bow):
    for tid,prob in sorted(lda.get_document_topics(bow, 0.0),
                           key=lambda x:x[1], reverse=True)[:TOP_K_PER_CALL]:
        if prob<MIN_PROB_TO_KEEP: continue
        detail.append({"call_id":cid,"timestamp":ts,
                       "topic_id":tid,"weight":prob,"keywords":kw_cache[tid]})
detail_df=pd.DataFrame(detail).sort_values(["timestamp","weight"],ascending=[True,False])
detail_df.to_csv(DETAIL_CSV,index=False,date_format="%Y-%m-%d %H:%M:%S")
pd.options.display.max_colwidth=80
display(detail_df.head(15))

# ---------- quick plot --------------------------
plt.figure(figsize=(12,4))
for tid in range(best_k):
    plt.plot(topic_df["timestamp"], topic_df[f"T{tid:02}"], label=f"T{tid:02}")
plt.legend(ncol=4,fontsize=8); plt.grid(alpha=.3)
plt.title("Topic weights over time"); plt.tight_layout(); plt.show()
# Out:
# Split → 71 calls
#   0%|          | 0/71 [00:00<?, ?it/s]
# Vocabulary size: 4024
# k= 5 → UMass -6.857
# k= 6 → UMass -6.728
# k= 7 → UMass -6.083
# k= 8 → UMass -6.143
# k= 9 → UMass -5.372
# k=10 → UMass -4.780
# k=11 → UMass -6.003
# k=12 → UMass -5.000
# k=13 → UMass -4.918
# k=14 → UMass -5.563
# k=15 → UMass -5.462
# k=16 → UMass -5.049
# k=17 → UMass -4.122
# k=18 → UMass -4.032
# k=19 → UMass -4.724
# k=20 → UMass -3.593
#
# ✅  Best model: k=20  (UMass=-3.593)
# [T00]  alog , salary , packet , technical , hiring , paulo , smart , stearn , rebate , jaffray , piper , culture
# [T01]  ai , caller , cooling , router , cpu , inference , liquid , training , dialogue , chip , gpu , face
# [T02]  division , alog , isle , piper , jaffray , synergy , gray , proof , intelligence , kelleher , brigantine , llc
# [T03]  llc , saleable , bad , manny , excess , suisse , advisor , mindful , self , isle , street , conservative
# [T04]  margie , backaus , compensation , sellable , ethernet , survey , frequency , oppenheimer , satisfaction , variable , study , canaccord
# [T05]  lifetime , passion , bump , onetime , link , honest , covid , commencement , distraction , cosmetic , ern , worker
# [T06]  adaire , training , inference , dilutive , custom , ai , caller , renewable , resale , segmentation , tam , interface
# [T07]  ai , stifel , investigation , chip , redevelopment , audit , kilowatt , independent , posture , caution , training , spread
# [T08]  gic , inflationary , delighted , datacenter , pass , hedging , chip , climate , inflation , franchise , pandemic , mainone
# [T09]  packet , timeline , bare , ecx , downward , grooming , frame , streaming , word , g , axtel , automation
# [T10]  margie , backaus , sellable , ixeurope , meter , adam , tenant , anchor , cannacord , rodney , suisse , brother
# [T11]  adaire , ai , camp , chip , infomart , llc , inference , training , franchise , spectrum , kilowatt , up
# [T12]  synergy , ethernet , concession , covid , smart , packet , prudent , culpeper , saleable , friction , launch , crisis
# [T13]  budgetary , setting , division , plant , reflective , estimate , basement , deutsche , isle , nontrivial , magnetic , softness
# [T14]  division , infomart , camp , metronode , dedicated , ancotel , pvc , fuel , productive , itconic , nonrecurring , gas
# [T15]  division , ancotel , gray , tone , rep , basket , multitiered , auty , merrill , goldman , rp , feasibility
# [T16]  isle , llc , synergy , divestiture , charlesmeyer , jvs , entity , deck , broker , regulatory , brexit , uptake
# [T17]  bat , backend , foursquare , rent , attributable , calculation , repurchase , plr , melbourne , indicative , organizational , purge
# [T18]  llc , jefferie , qrs , broker , plr , t , taxable , enablement , alog , melbourne , adjusted , characteristic
# [T19]  ex , srinivas , datacenter , anantha , allowance , brother , pickup , adam , failure , piper , ethernet , saleable
# Saved /content/call_topics.csv
#      call_id  timestamp  topic_id    weight  \
# 23   call_id  timestamp         8  0.998131
# 119  call_id  timestamp        10  0.998085
# 55   call_id  timestamp         3  0.997956
# 94   call_id  timestamp         2  0.997857
# 78   call_id  timestamp        15  0.997828
# 4    call_id  timestamp        11  0.997794
# 9    call_id  timestamp         1  0.997759
# 22   call_id  timestamp         8  0.997718
# 66   call_id  timestamp        16  0.997704
# 16   call_id  timestamp         6  0.997704
# 65   call_id  timestamp        16  0.997652
# 102  call_id  timestamp        12  0.997652
# 104  call_id  timestamp        19  0.997646
# 64   call_id  timestamp        16  0.997644
# 72   call_id  timestamp         2  0.997630
#
#                                                                             keywords
# 23   gic, inflationary, delighted, datacenter, pass, hedging, chip, climate, infl...
# 119  margie, backaus, sellable, ixeurope, meter, adam, tenant, anchor, cannacord,...
# 55           llc, saleable, bad, manny, excess, suisse, advisor, mindful, self, isle
# 94   division, alog, isle, piper, jaffray, synergy, gray, proof, intelligence, ke...
# 78   division, ancotel, gray, tone, rep, basket, multitiered, auty, merrill, goldman
# 4    adaire, ai, camp, chip, infomart, llc, inference, training, franchise, spectrum
# 9      ai, caller, cooling, router, cpu, inference, liquid, training, dialogue, chip
# 22   gic, inflationary, delighted, datacenter, pass, hedging, chip, climate, infl...
# 66   isle, llc, synergy, divestiture, charlesmeyer, jvs, entity, deck, broker, re...
# 16   adaire, training, inference, dilutive, custom, ai, caller, renewable, resale...
# 65   isle, llc, synergy, divestiture, charlesmeyer, jvs, entity, deck, broker, re...
# 102  synergy, ethernet, concession, covid, smart, packet, prudent, culpeper, sale...
# 104  ex, srinivas, datacenter, anantha, allowance, brother, pickup, adam, failure...
# 64   isle, llc, synergy, divestiture, charlesmeyer, jvs, entity, deck, broker, re...
# 72   division, alog, isle, piper, jaffray, synergy, gray, proof, intelligence, ke...
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['topic_id'].plot(kind='hist', bins=20, title='topic_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['weight'].plot(kind='hist', bins=20, title='weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='topic_id', y='weight', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['timestamp']
#   ys = series['topic_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('timestamp')
# _ = plt.ylabel('topic_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['timestamp']
#   ys = series['weight']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('timestamp')
# _ = plt.ylabel('weight')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['timestamp']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'timestamp'}, axis=1)
#               .sort_values('timestamp', ascending=True))
#   xs = counted['timestamp']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('timestamp', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('timestamp')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['topic_id'].plot(kind='line', figsize=(8, 4), title='topic_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['weight'].plot(kind='line', figsize=(8, 4), title='weight')
# plt.gca().spines[['top', 'right']].set_visible(False)
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
# 🔄  Re-generate per-call topic detail table with year/quarter cols
import re, pandas as pd

kw_cache = {t: ", ".join(w for w, _ in lda.show_topic(t, topn=10))
            for t in range(lda.num_topics)}

records = []
for meta_row, bow in zip(meta, corpus_bow):
    cid = meta_row["call_id"]
    ts  = meta_row["timestamp"]

    m = re.match(r"(?P<year>\d{4})-Q(?P<qtr>[1-4])", cid)
    year, qtr = int(m["year"]), int(m["qtr"])

    for tid, prob in sorted(lda.get_document_topics(bow, 0.0),
                            key=lambda x: x[1], reverse=True)[:TOP_K_PER_CALL]:
        if prob < MIN_PROB_TO_KEEP:
            continue
        records.append({
            "call_id" : cid,
            "year"    : year,
            "quarter" : qtr,
            "timestamp": ts,
            "topic_id": tid,
            "weight"  : prob,
            "keywords": kw_cache[tid]
        })

detail_df = (pd.DataFrame(records)
               .sort_values(["timestamp", "weight"], ascending=[True, False]))

detail_df.to_csv(DETAIL_CSV, index=False,
                 date_format="%Y-%m-%d %H:%M:%S")

pd.options.display.max_colwidth = 100
display(detail_df.tail(20))
print(f"✓ {DETAIL_CSV} rewritten with call_id, year, quarter, timestamp.")
# Out:
#     call_id  year  quarter           timestamp  topic_id    weight  \
# 18  2022-Q3  2022        3 2022-11-02 17:30:00         1  0.700603
# 19  2022-Q3  2022        3 2022-11-02 17:30:00        11  0.296903
# 17  2022-Q4  2022        4 2023-02-15 17:30:00         8  0.997476
# 16  2023-Q1  2023        1 2023-05-03 17:30:00         6  0.997704
# 11  2023-Q2  2023        2 2023-08-02 17:30:00        14  0.348373
# 12  2023-Q2  2023        2 2023-08-02 17:30:00         8  0.219968
# 13  2023-Q2  2023        2 2023-08-02 17:30:00        12  0.168461
# 14  2023-Q2  2023        2 2023-08-02 17:30:00         1  0.154494
# 15  2023-Q2  2023        2 2023-08-02 17:30:00        18  0.106786
# 10  2023-Q3  2023        3 2023-10-25 17:30:00         7  0.993381
# 9   2023-Q4  2023        4 2024-02-14 17:30:00         1  0.997759
# 7   2024-Q1  2024        1 2024-05-09 17:30:00         7  0.970681
# 8   2024-Q1  2024        1 2024-05-09 17:30:00        10  0.027716
# 5   2024-Q2  2024        2 2024-08-07 17:30:00        11  0.758991
# 6   2024-Q2  2024        2 2024-08-07 17:30:00         6  0.239262
# 4   2024-Q3  2024        3 2024-10-30 17:30:00        11  0.997794
# 2   2024-Q4  2024        4 2025-02-12 17:30:00         6  0.796343
# 3   2024-Q4  2024        4 2025-02-12 17:30:00        11  0.201713
# 0   2025-Q1  2025        1 2025-04-30 17:30:00        16  0.716002
# 1   2025-Q1  2025        1 2025-04-30 17:30:00        11  0.281940
#
#                                                                                           keywords
# 18                   ai, caller, cooling, router, cpu, inference, liquid, training, dialogue, chip
# 19                 adaire, ai, camp, chip, infomart, llc, inference, training, franchise, spectrum
# 17    gic, inflationary, delighted, datacenter, pass, hedging, chip, climate, inflation, franchise
# 16      adaire, training, inference, dilutive, custom, ai, caller, renewable, resale, segmentation
# 11         division, infomart, camp, metronode, dedicated, ancotel, pvc, fuel, productive, itconic
# 12    gic, inflationary, delighted, datacenter, pass, hedging, chip, climate, inflation, franchise
# 13      synergy, ethernet, concession, covid, smart, packet, prudent, culpeper, saleable, friction
# 14                   ai, caller, cooling, router, cpu, inference, liquid, training, dialogue, chip
# 15                        llc, jefferie, qrs, broker, plr, t, taxable, enablement, alog, melbourne
# 10  ai, stifel, investigation, chip, redevelopment, audit, kilowatt, independent, posture, caution
# 9                    ai, caller, cooling, router, cpu, inference, liquid, training, dialogue, chip
# 7   ai, stifel, investigation, chip, redevelopment, audit, kilowatt, independent, posture, caution
# 8              margie, backaus, sellable, ixeurope, meter, adam, tenant, anchor, cannacord, rodney
# 5                  adaire, ai, camp, chip, infomart, llc, inference, training, franchise, spectrum
# 6       adaire, training, inference, dilutive, custom, ai, caller, renewable, resale, segmentation
# 4                  adaire, ai, camp, chip, infomart, llc, inference, training, franchise, spectrum
# 2       adaire, training, inference, dilutive, custom, ai, caller, renewable, resale, segmentation
# 3                  adaire, ai, camp, chip, infomart, llc, inference, training, franchise, spectrum
# 0             isle, llc, synergy, divestiture, charlesmeyer, jvs, entity, deck, broker, regulatory
# 1                  adaire, ai, camp, chip, infomart, llc, inference, training, franchise, spectrum
# ✓ /content/call_topic_details.csv rewritten with call_id, year, quarter, timestamp.
