# %%
import os

os.environ["API_KEY"] = "your_api_key_here"  # Set your API key here

# Example: Accessing it right after setting
print(os.environ["API_KEY"])
# Out:
# XokeN0fDHyRtoZaB9HbVXCNd3uv5Piw4

# %%
import os
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from datetime import datetime, timedelta
import time
import concurrent.futures
from functools import partial

#############################################################################
# 1. Fetch S&P 500 Tickers
#############################################################################
def get_sp500_tickers():
    """
    Retrieves the list of S&P 500 tickers from Wikipedia.
    Returns a list of ticker symbols.
    """
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    tables = pd.read_html(url)
    df = tables[0]
    tickers = df["Symbol"].tolist()
    # Replace '.' with '-' if needed
    tickers = [t.replace(".", "-") for t in tickers]
    return tickers

#############################################################################
# 2. Fetch Price Data from FMP
#############################################################################
def get_price_data_fmp(ticker, apikey, from_date="1900-01-01", to_date=None):
    """
    Fetch daily adjusted close data for `ticker` from FinancialModelingPrep.
    Returns a sorted DataFrame with 'Adj Close' among other columns.

    Requirements:
      - A valid FMP API key.
      - Ticker symbol, e.g. "AAPL".
      - from_date / to_date in "YYYY-MM-DD" format.
    """
    if to_date is None:
        to_date = datetime.today().strftime("%Y-%m-%d")
    url = (
        f"https://financialmodelingprep.com/api/v3/historical-price-full/{ticker}"
        f"?from={from_date}&to={to_date}&apikey={apikey}"
    )
    resp = requests.get(url)
    if resp.status_code != 200:
        raise Exception(f"API request for {ticker} failed with status code {resp.status_code}")
    data = resp.json()
    if "historical" not in data:
        raise Exception(f"No 'historical' data found for {ticker}.")

    df = pd.DataFrame(data["historical"])
    df["date"] = pd.to_datetime(df["date"])
    df.set_index("date", inplace=True)
    df.sort_index(inplace=True)
    # Rename if needed
    if "adjClose" in df.columns:
        df.rename(columns={"adjClose": "Adj Close"}, inplace=True)
    if "Adj Close" not in df.columns:
        raise ValueError(f"No 'Adj Close' in the data for {ticker}.")

    return df

#############################################################################
# 3. Ornstein-Uhlenbeck Fit
#############################################################################
def fit_ou_mle(X, dt=1.0):
    """
    Fit an Ornstein–Uhlenbeck process by closed-form MLE:
       dX = kappa*(mu - X)*dt + sigma*dW

    Returns (kappa, mu, sigma, half_life).
    Raises ValueError if not mean-reverting (Phi out of (0,1)).
    """
    X = np.asarray(X)
    N = len(X)
    if N < 2:
        raise ValueError("Need at least 2 data points for OU model.")

    X_t   = X[:-1]
    X_tp1 = X[1:]
    N_float = float(N - 1)

    S_x   = np.sum(X_t)
    S_y   = np.sum(X_tp1)
    S_xx  = np.sum(X_t * X_t)
    S_xy  = np.sum(X_t * X_tp1)

    num = (N_float * S_xy) - (S_x * S_y)
    den = (N_float * S_xx) - (S_x * S_x)
    Phi = num / den

    if not (0 < Phi < 1):
        raise ValueError(f"Estimated Phi={Phi:.4f} out of (0,1). Not mean-reverting.")

    kappa = -np.log(Phi) / dt
    mu    = (S_y - Phi*S_x) / (N_float*(1 - Phi))

    a = mu*(1 - Phi)
    resid = X_tp1 - a - Phi*X_t
    var_res = np.sum(resid**2) / N_float

    sigma_sq = 2*kappa*var_res / (1 - Phi**2)
    if sigma_sq < 0:
        raise ValueError(f"Negative sigma^2 estimated ({sigma_sq:.4f}).")
    sigma = np.sqrt(sigma_sq)

    half_life = np.log(2)/kappa
    return kappa, mu, sigma, half_life

def detrend_and_fit_ou(price_series):
    """
    1) Fit linear regression: Price(t) = intercept + slope*t
    2) residual = Price - (intercept + slope*t)
    3) Fit OU to the residual.

    Returns a dict with:
      intercept, slope, r2_trend, residual
      ou_kappa, ou_mu, ou_sigma, ou_half_life
      or ou_error if fails
    """
    N = len(price_series)
    t_idx = np.arange(N)

    X_lr = sm.add_constant(t_idx)
    lr = sm.OLS(price_series.values, X_lr).fit()
    intercept, slope = lr.params
    fitted_trend = intercept + slope*t_idx
    residual = price_series.values - fitted_trend

    out = {
        "intercept": intercept,
        "slope": slope,
        "r2_trend": lr.rsquared,
        "residual": residual
    }

    try:
        kappa, mu_resid, sigma, hl = fit_ou_mle(residual, dt=1.0)
        out["ou_kappa"] = kappa
        out["ou_mu"] = mu_resid
        out["ou_sigma"] = sigma
        out["ou_half_life"] = hl
    except ValueError as e:
        out["ou_error"] = str(e)

    return out

#############################################################################
# 4. Momentum Filter & Backtest
#############################################################################
def compute_momentum(price_series, window=5):
    """
    Simple momentum measure:
    MOM_t = (P_t - P_{t-window}) / P_{t-window}
    """
    return (price_series - price_series.shift(window)) / price_series.shift(window)

def backtest_mr_with_momentum(price_series, residual, mu_resid, sigma,
                              z_thresh=2.0, mom_window=5, mom_thresh=0.0):
    """
    Combine OU-based Z-score with a momentum filter:
      Zscore = (residual - mu_resid)/sigma
      Momentum = (P_t - P_{t-5})/P_{t-5}

    Trading Rules:
      - If Zscore > +z_thresh AND momentum < mom_thresh => short
      - If Zscore < -z_thresh AND momentum > -mom_thresh => long
      - Else => flat
    """
    df_bt = pd.DataFrame(index=price_series.index)
    df_bt["price"] = price_series.values
    df_bt["returns"] = df_bt["price"].pct_change().fillna(0.0)

    # Z-score
    zscore = (residual - mu_resid)/sigma
    df_bt["zscore"] = zscore

    # Momentum
    mom = compute_momentum(price_series, window=mom_window)
    df_bt["momentum"] = mom.fillna(0.0)

    position = np.zeros(len(df_bt))
    for i in range(len(df_bt)):
        z = df_bt["zscore"].iloc[i]
        mo = df_bt["momentum"].iloc[i]
        # Overbought => short if momentum not too bullish
        if z > z_thresh and mo < mom_thresh:
            position[i] = -1
        # Oversold => long if momentum not too bearish
        elif z < -z_thresh and mo > -mom_thresh:
            position[i] = 1
        else:
            position[i] = 0

    df_bt["position"] = position

    df_bt["strategy_pnl"] = df_bt["position"].shift(1)*df_bt["returns"]
    df_bt.loc[df_bt.index[0], "strategy_pnl"] = 0.0

    df_bt["strategy_cumret"] = (1.0 + df_bt["strategy_pnl"]).cumprod()
    df_bt["buyhold_pnl"] = df_bt["returns"]
    df_bt["buyhold_cumret"] = (1.0 + df_bt["buyhold_pnl"]).cumprod()

    # Also store the zscore for final day usage
    return df_bt

#############################################################################
# 5. Performance Metrics
#############################################################################
def compute_performance_stats(pnl_series, freq_per_year=252):
    """
    Given daily (or each-step) pnl, compute:
      - annualized return
      - annualized volatility
      - sharpe ratio
    """
    pnl_series = pnl_series.dropna()
    daily_mean = pnl_series.mean()
    daily_std  = pnl_series.std(ddof=1)

    ann_return = (1 + daily_mean)**freq_per_year - 1
    ann_vol    = daily_std*np.sqrt(freq_per_year)
    if ann_vol > 1e-10:
        sharpe = ann_return/ann_vol
    else:
        sharpe = np.nan
    return ann_return, ann_vol, sharpe

#############################################################################
# 6. Current Signal & Forecast
#############################################################################
def compute_current_signal(price_series, intercept, slope, mu_resid, sigma, kappa, z_thresh=2.0):
    """
    - price_series: The entire historical 'Adj Close'.
    - intercept, slope: from Trend fit
    - mu_resid, sigma, kappa: from OU residual fit
    - z_thresh: Z-score threshold

    We'll assume the last day is our 'current day'.
    Compute the current Z-score:
       z_current = (Residual_current - mu_resid)/sigma
    If z_current > +z_thresh => "SHORT"
    If z_current < -z_thresh => "LONG"
    Else => "NONE"

    Return:
      - current_signal (LONG/SHORT/NONE)
      - revert_price
      - time_to_half (half-life)
      - time_to_90pct (ln(10)/kappa)
      - expected_pct_return
      - last_date
    """

    # Last day index & price
    last_date = price_series.index[-1]
    current_price = price_series.iloc[-1]
    N = len(price_series)

    # Current trend estimate
    current_trend = intercept + slope*(N-1)  # t_idx = N-1
    # Residual_current = P_{last} - (trend_{last})
    residual_current = current_price - current_trend
    # Z-score
    z_current = (residual_current - mu_resid)/sigma

    # Basic reversion times
    half_life = np.log(2)/kappa if kappa>1e-10 else np.nan
    t_90pct   = np.log(10)/kappa if kappa>1e-10 else np.nan

    # revert_price = current_trend + mu_resid
    revert_price = current_trend + mu_resid

    # Determine signal
    if z_current > z_thresh:
        current_signal = "SHORT"
    elif z_current < -z_thresh:
        current_signal = "LONG"
    else:
        current_signal = "NONE"

    # Expected % return from current_price to revert_price:
    if current_signal == "LONG":
        expected_pct_return = (revert_price - current_price)/current_price * 100
    elif current_signal == "SHORT":
        expected_pct_return = (current_price - revert_price)/current_price * 100
    else:
        expected_pct_return = 0.0

    # For "last signal date," if current day is a signal then use it
    last_signal_date = None
    if abs(z_current) >= z_thresh:
        last_signal_date = last_date
    else:
        # (Advanced search can be implemented if needed)
        pass

    # Expected closing dates based on reversion times
    expected_closing_date_half = pd.NaT
    expected_closing_date_90   = pd.NaT
    if pd.notnull(half_life):
        expected_closing_date_half = last_date + pd.Timedelta(days=half_life)
    if pd.notnull(t_90pct):
        expected_closing_date_90 = last_date + pd.Timedelta(days=t_90pct)

    return {
        "last_date": str(last_date.date()),
        "z_current": z_current,
        "current_signal": current_signal,
        "revert_price": revert_price,
        "time_to_half_revert": half_life,
        "time_to_90pct_revert": t_90pct,
        "expected_pct_return": expected_pct_return,
        "last_signal_date": str(last_signal_date.date()) if last_signal_date else None,
        "expected_date_half": str(expected_closing_date_half.date()) if expected_closing_date_half is not pd.NaT else None,
        "expected_date_90": str(expected_closing_date_90.date()) if expected_closing_date_90 is not pd.NaT else None
    }

#############################################################################
# 7. Analyze Ticker
#############################################################################
def analyze_ticker(ticker, api_key, from_date, to_date,
                   z_thresh=2.0, mom_window=5, mom_thresh=0.0):
    """
    1) Fetch 2y daily data for `ticker`.
    2) Trend+OU residual analysis
    3) If OU is valid, backtest the momentum-filtered MR strategy
    4) Compute a 'current signal' & forecast
    5) Return a summary dict with details
    """
    result = {"ticker": ticker}
    try:
        df = get_price_data_fmp(ticker, api_key, from_date, to_date)
        price_series = df["Adj Close"].copy()
        if len(price_series) < 30:
            result["error"] = "Not enough data points."
            return result

        # Trend+OU
        model_res = detrend_and_fit_ou(price_series)
        result["trend_intercept"] = model_res["intercept"]
        result["trend_slope"] = model_res["slope"]
        result["trend_r2"] = model_res["r2_trend"]
        result["data_points"] = len(price_series)
        result["start_date"] = str(price_series.index[0].date())
        result["end_date"]   = str(price_series.index[-1].date())

        if "ou_error" in model_res:
            result["ou_error"] = model_res["ou_error"]
            return result

        kappa    = model_res["ou_kappa"]
        mu_resid = model_res["ou_mu"]
        sigma    = model_res["ou_sigma"]
        hl       = model_res["ou_half_life"]

        result["ou_kappa"] = kappa
        result["ou_mu"] = mu_resid
        result["ou_sigma"] = sigma
        result["ou_half_life"] = hl

        # Backtest
        residual = model_res["residual"]
        df_bt = backtest_mr_with_momentum(price_series, residual, mu_resid, sigma,
                                          z_thresh=z_thresh,
                                          mom_window=mom_window,
                                          mom_thresh=mom_thresh)

        # Performance Metrics
        strat_annr, strat_vol, strat_sharpe = compute_performance_stats(df_bt["strategy_pnl"])
        bh_annr, bh_vol, bh_sharpe = compute_performance_stats(df_bt["buyhold_pnl"])

        result["strategy_ann_return"] = strat_annr
        result["strategy_ann_vol"]    = strat_vol
        result["strategy_sharpe"]     = strat_sharpe
        result["buyhold_ann_return"]  = bh_annr
        result["buyhold_ann_vol"]     = bh_vol
        result["buyhold_sharpe"]      = bh_sharpe

        # Current Signal & Forecast
        current_sig_info = compute_current_signal(price_series,
                                                  model_res["intercept"],
                                                  model_res["slope"],
                                                  mu_resid,
                                                  sigma,
                                                  kappa,
                                                  z_thresh=z_thresh)

        result.update(current_sig_info)

    except Exception as e:
        result["error"] = str(e)
    return result

#############################################################################
# 8. MAIN Loop over S&P 500 using Parallel Processing and Save to Google Drive
#############################################################################
def main():
    api_key   = os.environ.get("API_KEY")  # <-- Replace with your valid FMP API key
    days_hist = 730  # 2 years
    to_date   = datetime.today().strftime("%Y-%m-%d")
    from_date = (datetime.today() - timedelta(days=days_hist)).strftime("%Y-%m-%d")

    sp500_tickers = get_sp500_tickers()
    print(f"Found {len(sp500_tickers)} S&P 500 tickers.")

    # Use parallel processing with 8 CPU cores
    func = partial(analyze_ticker, api_key=api_key, from_date=from_date, to_date=to_date,
                   z_thresh=2.0, mom_window=5, mom_thresh=0.0)
    with concurrent.futures.ProcessPoolExecutor(max_workers=8) as executor:
        results = list(executor.map(func, sp500_tickers))

    # Print results in the original ticker order
    for i, (ticker, res) in enumerate(zip(sp500_tickers, results), start=1):
        print(f"\n[{i}/{len(sp500_tickers)}] Analyzing {ticker} ...")
        if "error" in res:
            print(f"  Error: {res['error']}")
        else:
            pts = res.get("data_points", 0)
            sd = res.get("start_date", "?")
            ed = res.get("end_date", "?")
            print(f"  Data Points: {pts} from {sd} to {ed}")
            if "ou_error" in res:
                print(f"  OU Error => {res['ou_error']}")
            else:
                kappa  = res["ou_kappa"]
                hl     = res["ou_half_life"]
                s_annr = res["strategy_ann_return"]*100
                s_shp  = res["strategy_sharpe"]
                b_annr = res["buyhold_ann_return"]*100
                b_shp  = res["buyhold_sharpe"]
                print(f"  OU => kappa={kappa:.4f}, half-life={hl:.2f} days")
                print(f"  Strategy => {s_annr:.2f}% annual, Sharpe={s_shp:.2f}")
                print(f"  Buy&Hold => {b_annr:.2f}% annual, Sharpe={b_shp:.2f}")

                c_sig   = res.get("current_signal", "NONE")
                r_price = res.get("revert_price", 0)
                half_t  = res.get("time_to_half_revert", 0)
                ninty_t = res.get("time_to_90pct_revert", 0)
                exp_ret = res.get("expected_pct_return", 0)
                sig_dt  = res.get("last_signal_date", None)
                half_dt = res.get("expected_date_half", None)
                ninty_dt= res.get("expected_date_90", None)
                print(f"  Current Signal: {c_sig}")
                if c_sig != "NONE":
                    print(f"    Revert Price: {r_price:.2f}")
                    print(f"    Time to 1/2 revert: {half_t:.1f} days (=> {half_dt})")
                    print(f"    Time to 90% revert: {ninty_t:.1f} days (=> {ninty_dt})")
                    print(f"    Expected % Return: {exp_ret:.2f}%")
                    print(f"    Last Signal Date: {sig_dt if sig_dt else 'N/A'}")

    df_res = pd.DataFrame(results)


    base_folder = "/workspaces/Stock-Market-Prediction/Quantative Investment/QI Output/Reversion"
    if not os.path.exists(base_folder):
        os.makedirs(base_folder)
    dated_folder = os.path.join(base_folder, datetime.today().strftime("%Y-%m-%d"))
    if not os.path.exists(dated_folder):
        os.makedirs(dated_folder)
    output_file = os.path.join(dated_folder, "sp500_mr_momentum_results_with_signal.csv")
    df_res.to_csv(output_file, index=False)
    print(f"\nDone. Results saved to '{output_file}'.")

if __name__ == "__main__":
    main()
# Out:
# Found 503 S&P 500 tickers.
#
# [1/503] Analyzing MMM ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0252, half-life=27.54 days
#   Strategy => 4.67% annual, Sharpe=0.29
#   Buy&Hold => 48.71% annual, Sharpe=1.48
#   Current Signal: SHORT
#     Revert Price: 147.69
#     Time to 1/2 revert: 27.5 days (=> 2025-06-12)
#     Time to 90% revert: 91.5 days (=> 2025-08-15)
#     Expected % Return: 3.54%
#     Last Signal Date: 2025-05-16
#
# [2/503] Analyzing AOS ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0132, half-life=52.42 days
#   Strategy => 15.03% annual, Sharpe=1.05
#   Buy&Hold => 6.36% annual, Sharpe=0.27
#   Current Signal: LONG
#     Revert Price: 74.84
#     Time to 1/2 revert: 52.4 days (=> 2025-07-07)
#     Time to 90% revert: 174.1 days (=> 2025-11-06)
#     Expected % Return: 6.12%
#     Last Signal Date: 2025-05-16
#
# [3/503] Analyzing ABT ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0221, half-life=31.43 days
#   Strategy => 3.05% annual, Sharpe=0.25
#   Buy&Hold => 15.79% annual, Sharpe=0.81
#   Current Signal: SHORT
#     Revert Price: 125.11
#     Time to 1/2 revert: 31.4 days (=> 2025-06-16)
#     Time to 90% revert: 104.4 days (=> 2025-08-28)
#     Expected % Return: 7.19%
#     Last Signal Date: 2025-05-16
#
# [4/503] Analyzing ABBV ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0295, half-life=23.50 days
#   Strategy => 16.42% annual, Sharpe=1.10
#   Buy&Hold => 20.52% annual, Sharpe=0.86
#   Current Signal: LONG
#     Revert Price: 197.91
#     Time to 1/2 revert: 23.5 days (=> 2025-06-08)
#     Time to 90% revert: 78.0 days (=> 2025-08-02)
#     Expected % Return: 7.55%
#     Last Signal Date: 2025-05-16
#
# [5/503] Analyzing ACN ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0187, half-life=37.10 days
#   Strategy => 9.75% annual, Sharpe=0.74
#   Buy&Hold => 9.69% annual, Sharpe=0.40
#   Current Signal: LONG
#     Revert Price: 343.84
#     Time to 1/2 revert: 37.1 days (=> 2025-06-22)
#     Time to 90% revert: 123.2 days (=> 2025-09-16)
#     Expected % Return: 8.23%
#     Last Signal Date: 2025-05-16
#
# [6/503] Analyzing ADBE ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0298, half-life=23.22 days
#   Strategy => 33.93% annual, Sharpe=1.82
#   Buy&Hold => 12.83% annual, Sharpe=0.37
#   Current Signal: LONG
#     Revert Price: 457.20
#     Time to 1/2 revert: 23.2 days (=> 2025-06-08)
#     Time to 90% revert: 77.1 days (=> 2025-08-01)
#     Expected % Return: 9.60%
#     Last Signal Date: 2025-05-16
#
# [7/503] Analyzing AMD ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0122, half-life=56.99 days
#   Strategy => -13.41% annual, Sharpe=-0.48
#   Buy&Hold => 19.36% annual, Sharpe=0.38
#   Current Signal: LONG
#     Revert Price: 136.29
#     Time to 1/2 revert: 57.0 days (=> 2025-07-11)
#     Time to 90% revert: 189.3 days (=> 2025-11-21)
#     Expected % Return: 16.32%
#     Last Signal Date: 2025-05-16
#
# [8/503] Analyzing AES ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0147, half-life=47.20 days
#   Strategy => 40.91% annual, Sharpe=1.76
#   Buy&Hold => -13.23% annual, Sharpe=-0.33
#   Current Signal: NONE
#
# [9/503] Analyzing AFL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0273, half-life=25.40 days
#   Strategy => 12.59% annual, Sharpe=1.32
#   Buy&Hold => 31.94% annual, Sharpe=1.52
#   Current Signal: LONG
#     Revert Price: 113.64
#     Time to 1/2 revert: 25.4 days (=> 2025-06-10)
#     Time to 90% revert: 84.4 days (=> 2025-08-08)
#     Expected % Return: 6.39%
#     Last Signal Date: 2025-05-16
#
# [10/503] Analyzing A ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0142, half-life=48.79 days
#   Strategy => 17.55% annual, Sharpe=1.07
#   Buy&Hold => -1.46% annual, Sharpe=-0.05
#   Current Signal: LONG
#     Revert Price: 131.19
#     Time to 1/2 revert: 48.8 days (=> 2025-07-03)
#     Time to 90% revert: 162.1 days (=> 2025-10-25)
#     Expected % Return: 15.31%
#     Last Signal Date: 2025-05-16
#
# [11/503] Analyzing APD ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0185, half-life=37.49 days
#   Strategy => 24.35% annual, Sharpe=1.71
#   Buy&Hold => 6.74% annual, Sharpe=0.24
#   Current Signal: LONG
#     Revert Price: 289.46
#     Time to 1/2 revert: 37.5 days (=> 2025-06-22)
#     Time to 90% revert: 124.5 days (=> 2025-09-17)
#     Expected % Return: 3.77%
#     Last Signal Date: 2025-05-16
#
# [12/503] Analyzing ABNB ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0318, half-life=21.81 days
#   Strategy => 31.38% annual, Sharpe=1.72
#   Buy&Hold => 21.92% annual, Sharpe=0.58
#   Current Signal: NONE
#
# [13/503] Analyzing AKAM ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0234, half-life=29.62 days
#   Strategy => 19.75% annual, Sharpe=0.92
#   Buy&Hold => 0.22% annual, Sharpe=0.01
#   Current Signal: LONG
#     Revert Price: 90.32
#     Time to 1/2 revert: 29.6 days (=> 2025-06-14)
#     Time to 90% revert: 98.4 days (=> 2025-08-22)
#     Expected % Return: 15.75%
#     Last Signal Date: 2025-05-16
#
# [14/503] Analyzing ALB ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0212, half-life=32.74 days
#   Strategy => 51.02% annual, Sharpe=1.97
#   Buy&Hold => -36.10% annual, Sharpe=-0.65
#   Current Signal: SHORT
#     Revert Price: 51.59
#     Time to 1/2 revert: 32.7 days (=> 2025-06-17)
#     Time to 90% revert: 108.8 days (=> 2025-09-01)
#     Expected % Return: 14.31%
#     Last Signal Date: 2025-05-16
#
# [15/503] Analyzing ARE ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0123, half-life=56.51 days
#   Strategy => -7.12% annual, Sharpe=-0.40
#   Buy&Hold => -12.86% annual, Sharpe=-0.41
#   Current Signal: LONG
#     Revert Price: 95.56
#     Time to 1/2 revert: 56.5 days (=> 2025-07-11)
#     Time to 90% revert: 187.7 days (=> 2025-11-19)
#     Expected % Return: 31.18%
#     Last Signal Date: 2025-05-16
#
# [16/503] Analyzing ALGN ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0226, half-life=30.65 days
#   Strategy => 23.30% annual, Sharpe=1.13
#   Buy&Hold => -11.51% annual, Sharpe=-0.26
#   Current Signal: NONE
#
# [17/503] Analyzing ALLE ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0225, half-life=30.77 days
#   Strategy => 5.28% annual, Sharpe=0.41
#   Buy&Hold => 20.85% annual, Sharpe=0.86
#   Current Signal: SHORT
#     Revert Price: 140.50
#     Time to 1/2 revert: 30.8 days (=> 2025-06-15)
#     Time to 90% revert: 102.2 days (=> 2025-08-26)
#     Expected % Return: 3.53%
#     Last Signal Date: 2025-05-16
#
# [18/503] Analyzing LNT ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0253, half-life=27.41 days
#   Strategy => 2.05% annual, Sharpe=0.21
#   Buy&Hold => 15.10% annual, Sharpe=0.79
#   Current Signal: SHORT
#     Revert Price: 61.01
#     Time to 1/2 revert: 27.4 days (=> 2025-06-12)
#     Time to 90% revert: 91.0 days (=> 2025-08-15)
#     Expected % Return: 2.35%
#     Last Signal Date: 2025-05-16
#
# [19/503] Analyzing ALL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0373, half-life=18.60 days
#   Strategy => 12.28% annual, Sharpe=1.08
#   Buy&Hold => 41.03% annual, Sharpe=1.68
#   Current Signal: NONE
#
# [20/503] Analyzing GOOGL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0249, half-life=27.80 days
#   Strategy => 0.74% annual, Sharpe=0.06
#   Buy&Hold => 22.08% annual, Sharpe=0.74
#   Current Signal: LONG
#     Revert Price: 183.62
#     Time to 1/2 revert: 27.8 days (=> 2025-06-12)
#     Time to 90% revert: 92.4 days (=> 2025-08-16)
#     Expected % Return: 10.49%
#     Last Signal Date: 2025-05-16
#
# [21/503] Analyzing GOOG ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0249, half-life=27.85 days
#   Strategy => 0.90% annual, Sharpe=0.07
#   Buy&Hold => 22.23% annual, Sharpe=0.75
#   Current Signal: LONG
#     Revert Price: 185.53
#     Time to 1/2 revert: 27.8 days (=> 2025-06-12)
#     Time to 90% revert: 92.5 days (=> 2025-08-16)
#     Expected % Return: 10.81%
#     Last Signal Date: 2025-05-16
#
# [22/503] Analyzing MO ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0194, half-life=35.68 days
#   Strategy => 19.49% annual, Sharpe=1.89
#   Buy&Hold => 26.23% annual, Sharpe=1.43
#   Current Signal: SHORT
#     Revert Price: 55.90
#     Time to 1/2 revert: 35.7 days (=> 2025-06-20)
#     Time to 90% revert: 118.5 days (=> 2025-09-11)
#     Expected % Return: 5.07%
#     Last Signal Date: 2025-05-16
#
# [23/503] Analyzing AMZN ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0280, half-life=24.80 days
#   Strategy => 20.39% annual, Sharpe=1.41
#   Buy&Hold => 40.11% annual, Sharpe=1.26
#   Current Signal: LONG
#     Revert Price: 220.76
#     Time to 1/2 revert: 24.8 days (=> 2025-06-09)
#     Time to 90% revert: 82.4 days (=> 2025-08-06)
#     Expected % Return: 7.38%
#     Last Signal Date: 2025-05-16
#
# [24/503] Analyzing AMCR ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0251, half-life=27.63 days
#   Strategy => -0.34% annual, Sharpe=-0.04
#   Buy&Hold => 3.60% annual, Sharpe=0.16
#   Current Signal: LONG
#     Revert Price: 10.04
#     Time to 1/2 revert: 27.6 days (=> 2025-06-12)
#     Time to 90% revert: 91.8 days (=> 2025-08-15)
#     Expected % Return: 6.34%
#     Last Signal Date: 2025-05-16
#
# [25/503] Analyzing AEE ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0131, half-life=52.90 days
#   Strategy => 9.19% annual, Sharpe=0.88
#   Buy&Hold => 13.79% annual, Sharpe=0.70
#   Current Signal: SHORT
#     Revert Price: 91.85
#     Time to 1/2 revert: 52.9 days (=> 2025-07-07)
#     Time to 90% revert: 175.7 days (=> 2025-11-07)
#     Expected % Return: 6.30%
#     Last Signal Date: 2025-05-16
#
# [26/503] Analyzing AEP ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0325, half-life=21.33 days
#   Strategy => 23.14% annual, Sharpe=2.15
#   Buy&Hold => 15.98% annual, Sharpe=0.79
#   Current Signal: NONE
#
# [27/503] Analyzing AXP ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0220, half-life=31.53 days
#   Strategy => 19.55% annual, Sharpe=1.48
#   Buy&Hold => 47.57% annual, Sharpe=1.73
#   Current Signal: NONE
#
# [28/503] Analyzing AIG ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0395, half-life=17.54 days
#   Strategy => 9.14% annual, Sharpe=0.97
#   Buy&Hold => 31.22% annual, Sharpe=1.44
#   Current Signal: NONE
#
# [29/503] Analyzing AMT ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0231, half-life=30.02 days
#   Strategy => 17.19% annual, Sharpe=1.29
#   Buy&Hold => 13.41% annual, Sharpe=0.50
#   Current Signal: NONE
#
# [30/503] Analyzing AWK ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0206, half-life=33.58 days
#   Strategy => 2.73% annual, Sharpe=0.21
#   Buy&Hold => 5.41% annual, Sharpe=0.24
#   Current Signal: SHORT
#     Revert Price: 134.68
#     Time to 1/2 revert: 33.6 days (=> 2025-06-18)
#     Time to 90% revert: 111.6 days (=> 2025-09-04)
#     Expected % Return: 5.53%
#     Last Signal Date: 2025-05-16
#
# [31/503] Analyzing AMP ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0243, half-life=28.55 days
#   Strategy => 6.06% annual, Sharpe=0.45
#   Buy&Hold => 37.63% annual, Sharpe=1.51
#   Current Signal: LONG
#     Revert Price: 541.72
#     Time to 1/2 revert: 28.6 days (=> 2025-06-13)
#     Time to 90% revert: 94.8 days (=> 2025-08-18)
#     Expected % Return: 3.35%
#     Last Signal Date: 2025-05-16
#
# [32/503] Analyzing AME ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0294, half-life=23.60 days
#   Strategy => 25.13% annual, Sharpe=2.24
#   Buy&Hold => 14.68% annual, Sharpe=0.69
#   Current Signal: NONE
#
# [33/503] Analyzing AMGN ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0164, half-life=42.33 days
#   Strategy => 11.58% annual, Sharpe=0.93
#   Buy&Hold => 17.72% annual, Sharpe=0.70
#   Current Signal: LONG
#     Revert Price: 311.81
#     Time to 1/2 revert: 42.3 days (=> 2025-06-27)
#     Time to 90% revert: 140.6 days (=> 2025-10-03)
#     Expected % Return: 14.46%
#     Last Signal Date: 2025-05-16
#
# [34/503] Analyzing APH ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0308, half-life=22.53 days
#   Strategy => 18.48% annual, Sharpe=1.28
#   Buy&Hold => 60.28% annual, Sharpe=2.02
#   Current Signal: SHORT
#     Revert Price: 77.66
#     Time to 1/2 revert: 22.5 days (=> 2025-06-07)
#     Time to 90% revert: 74.9 days (=> 2025-07-29)
#     Expected % Return: 10.61%
#     Last Signal Date: 2025-05-16
#
# [35/503] Analyzing ADI ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0401, half-life=17.29 days
#   Strategy => 8.67% annual, Sharpe=0.62
#   Buy&Hold => 18.36% annual, Sharpe=0.52
#   Current Signal: NONE
#
# [36/503] Analyzing ANSS ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0504, half-life=13.76 days
#   Strategy => 23.27% annual, Sharpe=1.44
#   Buy&Hold => 10.74% annual, Sharpe=0.38
#   Current Signal: SHORT
#     Revert Price: 333.74
#     Time to 1/2 revert: 13.8 days (=> 2025-05-29)
#     Time to 90% revert: 45.7 days (=> 2025-06-30)
#     Expected % Return: 3.72%
#     Last Signal Date: 2025-05-16
#
# [37/503] Analyzing AON ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0170, half-life=40.83 days
#   Strategy => 11.66% annual, Sharpe=1.02
#   Buy&Hold => 8.44% annual, Sharpe=0.40
#   Current Signal: NONE
#
# [38/503] Analyzing APA ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0359, half-life=19.33 days
#   Strategy => 29.68% annual, Sharpe=1.63
#   Buy&Hold => -17.63% annual, Sharpe=-0.41
#   Current Signal: NONE
#
# [39/503] Analyzing APO ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0198, half-life=35.09 days
#   Strategy => 11.89% annual, Sharpe=0.92
#   Buy&Hold => 63.24% annual, Sharpe=1.75
#   Current Signal: LONG
#     Revert Price: 157.99
#     Time to 1/2 revert: 35.1 days (=> 2025-06-20)
#     Time to 90% revert: 116.6 days (=> 2025-09-09)
#     Expected % Return: 9.84%
#     Last Signal Date: 2025-05-16
#
# [40/503] Analyzing AAPL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0206, half-life=33.71 days
#   Strategy => 11.21% annual, Sharpe=0.85
#   Buy&Hold => 14.61% annual, Sharpe=0.53
#   Current Signal: LONG
#     Revert Price: 230.80
#     Time to 1/2 revert: 33.7 days (=> 2025-06-18)
#     Time to 90% revert: 112.0 days (=> 2025-09-04)
#     Expected % Return: 9.25%
#     Last Signal Date: 2025-05-16
#
# [41/503] Analyzing AMAT ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0144, half-life=48.21 days
#   Strategy => 23.94% annual, Sharpe=1.02
#   Buy&Hold => 25.94% annual, Sharpe=0.62
#   Current Signal: LONG
#     Revert Price: 191.14
#     Time to 1/2 revert: 48.2 days (=> 2025-07-03)
#     Time to 90% revert: 160.1 days (=> 2025-10-23)
#     Expected % Return: 15.44%
#     Last Signal Date: 2025-05-16
#
# [42/503] Analyzing APTV ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0376, half-life=18.46 days
#   Strategy => 33.27% annual, Sharpe=2.01
#   Buy&Hold => -8.71% annual, Sharpe=-0.23
#   Current Signal: SHORT
#     Revert Price: 54.17
#     Time to 1/2 revert: 18.5 days (=> 2025-06-03)
#     Time to 90% revert: 61.3 days (=> 2025-07-16)
#     Expected % Return: 20.65%
#     Last Signal Date: 2025-05-16
#
# [43/503] Analyzing ACGL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0205, half-life=33.82 days
#   Strategy => 13.50% annual, Sharpe=1.19
#   Buy&Hold => 18.01% annual, Sharpe=0.74
#   Current Signal: LONG
#     Revert Price: 101.19
#     Time to 1/2 revert: 33.8 days (=> 2025-06-18)
#     Time to 90% revert: 112.3 days (=> 2025-09-05)
#     Expected % Return: 6.98%
#     Last Signal Date: 2025-05-16
#
# [44/503] Analyzing ADM ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0308, half-life=22.51 days
#   Strategy => 16.78% annual, Sharpe=1.60
#   Buy&Hold => -10.74% annual, Sharpe=-0.36
#   Current Signal: SHORT
#     Revert Price: 45.98
#     Time to 1/2 revert: 22.5 days (=> 2025-06-07)
#     Time to 90% revert: 74.8 days (=> 2025-07-29)
#     Expected % Return: 8.29%
#     Last Signal Date: 2025-05-16
#
# [45/503] Analyzing ANET ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0255, half-life=27.22 days
#   Strategy => 10.64% annual, Sharpe=0.66
#   Buy&Hold => 85.87% annual, Sharpe=1.73
#   Current Signal: LONG
#     Revert Price: 107.56
#     Time to 1/2 revert: 27.2 days (=> 2025-06-12)
#     Time to 90% revert: 90.4 days (=> 2025-08-14)
#     Expected % Return: 11.56%
#     Last Signal Date: 2025-05-16
#
# [46/503] Analyzing AJG ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0461, half-life=15.04 days
#   Strategy => 9.19% annual, Sharpe=1.26
#   Buy&Hold => 29.80% annual, Sharpe=1.49
#   Current Signal: SHORT
#     Revert Price: 326.18
#     Time to 1/2 revert: 15.0 days (=> 2025-05-31)
#     Time to 90% revert: 50.0 days (=> 2025-07-04)
#     Expected % Return: 4.67%
#     Last Signal Date: 2025-05-16
#
# [47/503] Analyzing AIZ ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0268, half-life=25.84 days
#   Strategy => 14.17% annual, Sharpe=1.19
#   Buy&Hold => 31.04% annual, Sharpe=1.31
#   Current Signal: LONG
#     Revert Price: 217.58
#     Time to 1/2 revert: 25.8 days (=> 2025-06-10)
#     Time to 90% revert: 85.8 days (=> 2025-08-09)
#     Expected % Return: 7.52%
#     Last Signal Date: 2025-05-16
#
# [48/503] Analyzing T ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0276, half-life=25.12 days
#   Strategy => 12.52% annual, Sharpe=0.98
#   Buy&Hold => 42.77% annual, Sharpe=1.79
#   Current Signal: SHORT
#     Revert Price: 25.68
#     Time to 1/2 revert: 25.1 days (=> 2025-06-10)
#     Time to 90% revert: 83.4 days (=> 2025-08-07)
#     Expected % Return: 7.36%
#     Last Signal Date: 2025-05-16
#
# [49/503] Analyzing ATO ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0187, half-life=37.14 days
#   Strategy => 13.31% annual, Sharpe=1.41
#   Buy&Hold => 20.82% annual, Sharpe=1.25
#   Current Signal: SHORT
#     Revert Price: 149.01
#     Time to 1/2 revert: 37.1 days (=> 2025-06-22)
#     Time to 90% revert: 123.4 days (=> 2025-09-16)
#     Expected % Return: 5.50%
#     Last Signal Date: 2025-05-16
#
# [50/503] Analyzing ADSK ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0260, half-life=26.71 days
#   Strategy => 10.25% annual, Sharpe=0.85
#   Buy&Hold => 26.89% annual, Sharpe=0.96
#   Current Signal: NONE
#
# [51/503] Analyzing ADP ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0269, half-life=25.81 days
#   Strategy => 8.57% annual, Sharpe=0.94
#   Buy&Hold => 26.68% annual, Sharpe=1.42
#   Current Signal: SHORT
#     Revert Price: 306.12
#     Time to 1/2 revert: 25.8 days (=> 2025-06-10)
#     Time to 90% revert: 85.7 days (=> 2025-08-09)
#     Expected % Return: 4.15%
#     Last Signal Date: 2025-05-16
#
# [52/503] Analyzing AZO ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0610, half-life=11.36 days
#   Strategy => 19.75% annual, Sharpe=2.44
#   Buy&Hold => 22.45% annual, Sharpe=1.04
#   Current Signal: SHORT
#     Revert Price: 3572.41
#     Time to 1/2 revert: 11.4 days (=> 2025-05-27)
#     Time to 90% revert: 37.7 days (=> 2025-06-22)
#     Expected % Return: 5.65%
#     Last Signal Date: 2025-05-16
#
# [53/503] Analyzing AVB ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0214, half-life=32.44 days
#   Strategy => 8.03% annual, Sharpe=0.77
#   Buy&Hold => 15.05% annual, Sharpe=0.72
#   Current Signal: LONG
#     Revert Price: 222.22
#     Time to 1/2 revert: 32.4 days (=> 2025-06-17)
#     Time to 90% revert: 107.8 days (=> 2025-08-31)
#     Expected % Return: 6.79%
#     Last Signal Date: 2025-05-16
#
# [54/503] Analyzing AVY ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0095, half-life=73.29 days
#   Strategy => 3.73% annual, Sharpe=0.26
#   Buy&Hold => 7.69% annual, Sharpe=0.37
#   Current Signal: LONG
#     Revert Price: 202.35
#     Time to 1/2 revert: 73.3 days (=> 2025-07-28)
#     Time to 90% revert: 243.5 days (=> 2026-01-14)
#     Expected % Return: 10.45%
#     Last Signal Date: 2025-05-16
#
# [55/503] Analyzing AXON ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0207, half-life=33.45 days
#   Strategy => 41.34% annual, Sharpe=2.15
#   Buy&Hold => 114.61% annual, Sharpe=2.49
#   Current Signal: SHORT
#     Revert Price: 613.43
#     Time to 1/2 revert: 33.4 days (=> 2025-06-18)
#     Time to 90% revert: 111.1 days (=> 2025-09-04)
#     Expected % Return: 16.33%
#     Last Signal Date: 2025-05-16
#
# [56/503] Analyzing BKR ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0217, half-life=31.95 days
#   Strategy => 4.57% annual, Sharpe=0.29
#   Buy&Hold => 24.78% annual, Sharpe=0.82
#   Current Signal: LONG
#     Revert Price: 41.09
#     Time to 1/2 revert: 32.0 days (=> 2025-06-16)
#     Time to 90% revert: 106.1 days (=> 2025-08-30)
#     Expected % Return: 8.74%
#     Last Signal Date: 2025-05-16
#
# [57/503] Analyzing BALL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0108, half-life=64.25 days
#   Strategy => 13.73% annual, Sharpe=0.82
#   Buy&Hold => 4.44% annual, Sharpe=0.16
#   Current Signal: LONG
#     Revert Price: 58.31
#     Time to 1/2 revert: 64.2 days (=> 2025-07-19)
#     Time to 90% revert: 213.4 days (=> 2025-12-15)
#     Expected % Return: 8.44%
#     Last Signal Date: 2025-05-16
#
# [58/503] Analyzing BAC ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0231, half-life=30.06 days
#   Strategy => 24.24% annual, Sharpe=2.06
#   Buy&Hold => 34.48% annual, Sharpe=1.31
#   Current Signal: LONG
#     Revert Price: 46.02
#     Time to 1/2 revert: 30.1 days (=> 2025-06-15)
#     Time to 90% revert: 99.9 days (=> 2025-08-23)
#     Expected % Return: 2.97%
#     Last Signal Date: 2025-05-16
#
# [59/503] Analyzing BAX ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0244, half-life=28.46 days
#   Strategy => 25.29% annual, Sharpe=1.40
#   Buy&Hold => -7.67% annual, Sharpe=-0.25
#   Current Signal: NONE
#
# [60/503] Analyzing BDX ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0337, half-life=20.59 days
#   Strategy => 12.08% annual, Sharpe=1.37
#   Buy&Hold => -12.61% annual, Sharpe=-0.52
#   Current Signal: LONG
#     Revert Price: 212.19
#     Time to 1/2 revert: 20.6 days (=> 2025-06-05)
#     Time to 90% revert: 68.4 days (=> 2025-07-23)
#     Expected % Return: 20.97%
#     Last Signal Date: 2025-05-16
#
# [61/503] Analyzing BRK-B ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0561, half-life=12.35 days
#   Strategy => 12.48% annual, Sharpe=1.63
#   Buy&Hold => 26.68% annual, Sharpe=1.63
#   Current Signal: NONE
#
# [62/503] Analyzing BBY ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0193, half-life=35.90 days
#   Strategy => 9.16% annual, Sharpe=0.43
#   Buy&Hold => 14.48% annual, Sharpe=0.40
#   Current Signal: LONG
#     Revert Price: 83.86
#     Time to 1/2 revert: 35.9 days (=> 2025-06-20)
#     Time to 90% revert: 119.2 days (=> 2025-09-12)
#     Expected % Return: 13.63%
#     Last Signal Date: 2025-05-16
#
# [63/503] Analyzing TECH ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0189, half-life=36.74 days
#   Strategy => 9.53% annual, Sharpe=0.50
#   Buy&Hold => -17.77% annual, Sharpe=-0.47
#   Current Signal: LONG
#     Revert Price: 62.50
#     Time to 1/2 revert: 36.7 days (=> 2025-06-21)
#     Time to 90% revert: 122.0 days (=> 2025-09-15)
#     Expected % Return: 27.15%
#     Last Signal Date: 2025-05-16
#
# [64/503] Analyzing BIIB ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0325, half-life=21.34 days
#   Strategy => 16.84% annual, Sharpe=1.30
#   Buy&Hold => -34.20% annual, Sharpe=-1.31
#   Current Signal: NONE
#
# [65/503] Analyzing BLK ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0222, half-life=31.24 days
#   Strategy => 26.99% annual, Sharpe=2.53
#   Buy&Hold => 28.55% annual, Sharpe=1.23
#   Current Signal: NONE
#
# [66/503] Analyzing BX ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0166, half-life=41.73 days
#   Strategy => 6.55% annual, Sharpe=0.40
#   Buy&Hold => 45.55% annual, Sharpe=1.31
#   Current Signal: LONG
#     Revert Price: 166.59
#     Time to 1/2 revert: 41.7 days (=> 2025-06-26)
#     Time to 90% revert: 138.6 days (=> 2025-10-01)
#     Expected % Return: 13.56%
#     Last Signal Date: 2025-05-16
#
# [67/503] Analyzing BK ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0307, half-life=22.58 days
#   Strategy => 7.07% annual, Sharpe=0.60
#   Buy&Hold => 57.23% annual, Sharpe=2.58
#   Current Signal: SHORT
#     Revert Price: 86.06
#     Time to 1/2 revert: 22.6 days (=> 2025-06-07)
#     Time to 90% revert: 75.0 days (=> 2025-07-30)
#     Expected % Return: 4.45%
#     Last Signal Date: 2025-05-16
#
# [68/503] Analyzing BA ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0172, half-life=40.32 days
#   Strategy => 45.41% annual, Sharpe=2.38
#   Buy&Hold => 6.48% annual, Sharpe=0.18
#   Current Signal: SHORT
#     Revert Price: 163.38
#     Time to 1/2 revert: 40.3 days (=> 2025-06-25)
#     Time to 90% revert: 134.0 days (=> 2025-09-26)
#     Expected % Return: 20.62%
#     Last Signal Date: 2025-05-16
#
# [69/503] Analyzing BKNG ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0320, half-life=21.66 days
#   Strategy => 21.92% annual, Sharpe=1.72
#   Buy&Hold => 45.37% annual, Sharpe=1.62
#   Current Signal: SHORT
#     Revert Price: 5062.01
#     Time to 1/2 revert: 21.7 days (=> 2025-06-06)
#     Time to 90% revert: 72.0 days (=> 2025-07-26)
#     Expected % Return: 4.80%
#     Last Signal Date: 2025-05-16
#
# [70/503] Analyzing BSX ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0424, half-life=16.33 days
#   Strategy => 13.08% annual, Sharpe=1.55
#   Buy&Hold => 44.20% annual, Sharpe=2.08
#   Current Signal: SHORT
#     Revert Price: 103.03
#     Time to 1/2 revert: 16.3 days (=> 2025-06-01)
#     Time to 90% revert: 54.3 days (=> 2025-07-09)
#     Expected % Return: 2.84%
#     Last Signal Date: 2025-05-16
#
# [71/503] Analyzing BMY ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0120, half-life=57.98 days
#   Strategy => 2.50% annual, Sharpe=0.13
#   Buy&Hold => -8.71% annual, Sharpe=-0.32
#   Current Signal: NONE
#
# [72/503] Analyzing AVGO ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0510, half-life=13.59 days
#   Strategy => 32.99% annual, Sharpe=1.81
#   Buy&Hold => 113.05% annual, Sharpe=2.18
#   Current Signal: SHORT
#     Revert Price: 217.14
#     Time to 1/2 revert: 13.6 days (=> 2025-05-29)
#     Time to 90% revert: 45.2 days (=> 2025-06-30)
#     Expected % Return: 5.02%
#     Last Signal Date: 2025-05-16
#
# [73/503] Analyzing BR ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0686, half-life=10.11 days
#   Strategy => 10.98% annual, Sharpe=1.57
#   Buy&Hold => 30.30% annual, Sharpe=1.53
#   Current Signal: NONE
#
# [74/503] Analyzing BRO ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0386, half-life=17.98 days
#   Strategy => 8.34% annual, Sharpe=0.99
#   Buy&Hold => 33.47% annual, Sharpe=1.68
#   Current Signal: LONG
#     Revert Price: 118.01
#     Time to 1/2 revert: 18.0 days (=> 2025-06-02)
#     Time to 90% revert: 59.7 days (=> 2025-07-14)
#     Expected % Return: 5.58%
#     Last Signal Date: 2025-05-16
#
# [75/503] Analyzing BF-B ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0354, half-life=19.59 days
#   Strategy => 12.99% annual, Sharpe=0.99
#   Buy&Hold => -20.27% annual, Sharpe=-0.70
#   Current Signal: SHORT
#     Revert Price: 32.32
#     Time to 1/2 revert: 19.6 days (=> 2025-06-04)
#     Time to 90% revert: 65.1 days (=> 2025-07-20)
#     Expected % Return: 10.44%
#     Last Signal Date: 2025-05-16
#
# [76/503] Analyzing BLDR ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0124, half-life=55.81 days
#   Strategy => 3.74% annual, Sharpe=0.16
#   Buy&Hold => 10.56% annual, Sharpe=0.24
#   Current Signal: LONG
#     Revert Price: 159.38
#     Time to 1/2 revert: 55.8 days (=> 2025-07-10)
#     Time to 90% revert: 185.4 days (=> 2025-11-17)
#     Expected % Return: 32.11%
#     Last Signal Date: 2025-05-16
#
# [77/503] Analyzing BG ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0201, half-life=34.51 days
#   Strategy => 12.63% annual, Sharpe=0.87
#   Buy&Hold => 0.53% annual, Sharpe=0.02
#   Current Signal: NONE
#
# [78/503] Analyzing BXP ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0226, half-life=30.63 days
#   Strategy => 24.10% annual, Sharpe=1.25
#   Buy&Hold => 33.56% annual, Sharpe=0.92
#   Current Signal: LONG
#     Revert Price: 74.72
#     Time to 1/2 revert: 30.6 days (=> 2025-06-15)
#     Time to 90% revert: 101.7 days (=> 2025-08-25)
#     Expected % Return: 10.12%
#     Last Signal Date: 2025-05-16
#
# [79/503] Analyzing CHRW ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0173, half-life=40.10 days
#   Strategy => 1.07% annual, Sharpe=0.07
#   Buy&Hold => 7.19% annual, Sharpe=0.24
#   Current Signal: NONE
#
# [80/503] Analyzing CDNS ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0305, half-life=22.73 days
#   Strategy => 12.30% annual, Sharpe=0.73
#   Buy&Hold => 29.84% annual, Sharpe=0.84
#   Current Signal: SHORT
#     Revert Price: 302.86
#     Time to 1/2 revert: 22.7 days (=> 2025-06-07)
#     Time to 90% revert: 75.5 days (=> 2025-07-30)
#     Expected % Return: 5.81%
#     Last Signal Date: 2025-05-16
#
# [81/503] Analyzing CZR ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0424, half-life=16.35 days
#   Strategy => 3.71% annual, Sharpe=0.18
#   Buy&Hold => -7.36% annual, Sharpe=-0.16
#   Current Signal: NONE
#
# [82/503] Analyzing CPT ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0200, half-life=34.57 days
#   Strategy => 12.01% annual, Sharpe=0.97
#   Buy&Hold => 13.10% annual, Sharpe=0.57
#   Current Signal: NONE
#
# [83/503] Analyzing CPB ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0175, half-life=39.66 days
#   Strategy => -1.30% annual, Sharpe=-0.11
#   Buy&Hold => -12.69% annual, Sharpe=-0.54
#   Current Signal: LONG
#     Revert Price: 40.04
#     Time to 1/2 revert: 39.7 days (=> 2025-06-24)
#     Time to 90% revert: 131.8 days (=> 2025-09-24)
#     Expected % Return: 12.72%
#     Last Signal Date: 2025-05-16
#
# [84/503] Analyzing COF ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0344, half-life=20.16 days
#   Strategy => 25.95% annual, Sharpe=1.81
#   Buy&Hold => 52.82% annual, Sharpe=1.56
#   Current Signal: NONE
#
# [85/503] Analyzing CAH ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0119, half-life=58.14 days
#   Strategy => 14.57% annual, Sharpe=1.27
#   Buy&Hold => 40.18% annual, Sharpe=1.85
#   Current Signal: SHORT
#     Revert Price: 134.47
#     Time to 1/2 revert: 58.1 days (=> 2025-07-13)
#     Time to 90% revert: 193.1 days (=> 2025-11-25)
#     Expected % Return: 12.82%
#     Last Signal Date: 2025-05-16
#
# [86/503] Analyzing KMX ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0348, half-life=19.94 days
#   Strategy => 50.27% annual, Sharpe=2.11
#   Buy&Hold => 4.01% annual, Sharpe=0.11
#   Current Signal: LONG
#     Revert Price: 76.09
#     Time to 1/2 revert: 19.9 days (=> 2025-06-04)
#     Time to 90% revert: 66.3 days (=> 2025-07-21)
#     Expected % Return: 13.14%
#     Last Signal Date: 2025-05-16
#
# [87/503] Analyzing CCL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0179, half-life=38.62 days
#   Strategy => 69.55% annual, Sharpe=2.45
#   Buy&Hold => 64.39% annual, Sharpe=1.34
#   Current Signal: NONE
#
# [88/503] Analyzing CARR ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0228, half-life=30.40 days
#   Strategy => 28.28% annual, Sharpe=1.59
#   Buy&Hold => 41.66% annual, Sharpe=1.34
#   Current Signal: NONE
#
# [89/503] Analyzing CAT ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0167, half-life=41.53 days
#   Strategy => 20.50% annual, Sharpe=1.36
#   Buy&Hold => 36.48% annual, Sharpe=1.25
#   Current Signal: LONG
#     Revert Price: 384.27
#     Time to 1/2 revert: 41.5 days (=> 2025-06-26)
#     Time to 90% revert: 138.0 days (=> 2025-09-30)
#     Expected % Return: 8.68%
#     Last Signal Date: 2025-05-16
#
# [90/503] Analyzing CBOE ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0347, half-life=19.96 days
#   Strategy => 11.74% annual, Sharpe=1.09
#   Buy&Hold => 29.46% annual, Sharpe=1.38
#   Current Signal: NONE
#
# [91/503] Analyzing CBRE ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0192, half-life=36.12 days
#   Strategy => 25.57% annual, Sharpe=1.37
#   Buy&Hold => 36.34% annual, Sharpe=1.25
#   Current Signal: NONE
#
# [92/503] Analyzing CDW ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0136, half-life=50.87 days
#   Strategy => 22.61% annual, Sharpe=1.64
#   Buy&Hold => 10.12% annual, Sharpe=0.37
#   Current Signal: LONG
#     Revert Price: 199.44
#     Time to 1/2 revert: 50.9 days (=> 2025-07-05)
#     Time to 90% revert: 169.0 days (=> 2025-10-31)
#     Expected % Return: 5.51%
#     Last Signal Date: 2025-05-16
#
# [93/503] Analyzing COR ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0216, half-life=32.02 days
#   Strategy => 18.63% annual, Sharpe=2.04
#   Buy&Hold => 33.05% annual, Sharpe=1.80
#   Current Signal: SHORT
#     Revert Price: 271.69
#     Time to 1/2 revert: 32.0 days (=> 2025-06-17)
#     Time to 90% revert: 106.4 days (=> 2025-08-30)
#     Expected % Return: 6.39%
#     Last Signal Date: 2025-05-16
#
# [94/503] Analyzing CNC ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0250, half-life=27.71 days
#   Strategy => 10.25% annual, Sharpe=0.62
#   Buy&Hold => 1.66% annual, Sharpe=0.06
#   Current Signal: NONE
#
# [95/503] Analyzing CNP ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0130, half-life=53.37 days
#   Strategy => 1.49% annual, Sharpe=0.14
#   Buy&Hold => 20.20% annual, Sharpe=1.03
#   Current Signal: SHORT
#     Revert Price: 33.61
#     Time to 1/2 revert: 53.4 days (=> 2025-07-08)
#     Time to 90% revert: 177.3 days (=> 2025-11-09)
#     Expected % Return: 10.42%
#     Last Signal Date: 2025-05-16
#
# [96/503] Analyzing CF ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0418, half-life=16.58 days
#   Strategy => 13.42% annual, Sharpe=0.81
#   Buy&Hold => 23.61% annual, Sharpe=0.78
#   Current Signal: SHORT
#     Revert Price: 84.05
#     Time to 1/2 revert: 16.6 days (=> 2025-06-01)
#     Time to 90% revert: 55.1 days (=> 2025-07-10)
#     Expected % Return: 4.25%
#     Last Signal Date: 2025-05-16
#
# [97/503] Analyzing CRL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0165, half-life=41.94 days
#   Strategy => 24.26% annual, Sharpe=1.19
#   Buy&Hold => -6.88% annual, Sharpe=-0.16
#   Current Signal: LONG
#     Revert Price: 171.27
#     Time to 1/2 revert: 41.9 days (=> 2025-06-26)
#     Time to 90% revert: 139.3 days (=> 2025-10-02)
#     Expected % Return: 21.49%
#     Last Signal Date: 2025-05-16
#
# [98/503] Analyzing SCHW ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0266, half-life=26.08 days
#   Strategy => 4.42% annual, Sharpe=0.38
#   Buy&Hold => 39.20% annual, Sharpe=1.32
#   Current Signal: SHORT
#     Revert Price: 81.52
#     Time to 1/2 revert: 26.1 days (=> 2025-06-11)
#     Time to 90% revert: 86.6 days (=> 2025-08-10)
#     Expected % Return: 8.08%
#     Last Signal Date: 2025-05-16
#
# [99/503] Analyzing CHTR ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0118, half-life=58.80 days
#   Strategy => 11.89% annual, Sharpe=0.66
#   Buy&Hold => 20.42% annual, Sharpe=0.54
#   Current Signal: SHORT
#     Revert Price: 356.51
#     Time to 1/2 revert: 58.8 days (=> 2025-07-13)
#     Time to 90% revert: 195.3 days (=> 2025-11-27)
#     Expected % Return: 16.56%
#     Last Signal Date: 2025-05-16
#
# [100/503] Analyzing CVX ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0421, half-life=16.45 days
#   Strategy => 10.62% annual, Sharpe=0.93
#   Buy&Hold => 1.89% annual, Sharpe=0.08
#   Current Signal: LONG
#     Revert Price: 149.82
#     Time to 1/2 revert: 16.5 days (=> 2025-06-01)
#     Time to 90% revert: 54.7 days (=> 2025-07-09)
#     Expected % Return: 5.43%
#     Last Signal Date: 2025-05-16
#
# [101/503] Analyzing CMG ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0095, half-life=72.63 days
#   Strategy => 4.20% annual, Sharpe=0.29
#   Buy&Hold => 16.35% annual, Sharpe=0.56
#   Current Signal: LONG
#     Revert Price: 59.11
#     Time to 1/2 revert: 72.6 days (=> 2025-07-27)
#     Time to 90% revert: 241.3 days (=> 2026-01-12)
#     Expected % Return: 12.97%
#     Last Signal Date: 2025-05-16
#
# [102/503] Analyzing CB ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0380, half-life=18.24 days
#   Strategy => 3.92% annual, Sharpe=0.42
#   Buy&Hold => 25.27% annual, Sharpe=1.30
#   Current Signal: LONG
#     Revert Price: 302.95
#     Time to 1/2 revert: 18.2 days (=> 2025-06-03)
#     Time to 90% revert: 60.6 days (=> 2025-07-15)
#     Expected % Return: 2.93%
#     Last Signal Date: 2025-05-16
#
# [103/503] Analyzing CHD ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0314, half-life=22.10 days
#   Strategy => 12.87% annual, Sharpe=1.77
#   Buy&Hold => 3.47% annual, Sharpe=0.18
#   Current Signal: LONG
#     Revert Price: 106.56
#     Time to 1/2 revert: 22.1 days (=> 2025-06-07)
#     Time to 90% revert: 73.4 days (=> 2025-07-28)
#     Expected % Return: 11.19%
#     Last Signal Date: 2025-05-16
#
# [104/503] Analyzing CI ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0228, half-life=30.42 days
#   Strategy => 4.74% annual, Sharpe=0.33
#   Buy&Hold => 18.73% annual, Sharpe=0.67
#   Current Signal: LONG
#     Revert Price: 338.23
#     Time to 1/2 revert: 30.4 days (=> 2025-06-15)
#     Time to 90% revert: 101.1 days (=> 2025-08-25)
#     Expected % Return: 5.39%
#     Last Signal Date: 2025-05-16
#
# [105/503] Analyzing CINF ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0397, half-life=17.46 days
#   Strategy => 4.87% annual, Sharpe=0.46
#   Buy&Hold => 26.77% annual, Sharpe=1.14
#   Current Signal: NONE
#
# [106/503] Analyzing CTAS ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0293, half-life=23.63 days
#   Strategy => 9.73% annual, Sharpe=0.92
#   Buy&Hold => 41.96% annual, Sharpe=1.91
#   Current Signal: NONE
#
# [107/503] Analyzing CSCO ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0124, half-life=56.00 days
#   Strategy => 6.69% annual, Sharpe=0.57
#   Buy&Hold => 20.04% annual, Sharpe=0.95
#   Current Signal: SHORT
#     Revert Price: 58.42
#     Time to 1/2 revert: 56.0 days (=> 2025-07-10)
#     Time to 90% revert: 186.0 days (=> 2025-11-18)
#     Expected % Return: 8.14%
#     Last Signal Date: 2025-05-16
#
# [108/503] Analyzing C ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0266, half-life=26.09 days
#   Strategy => 33.86% annual, Sharpe=2.41
#   Buy&Hold => 39.06% annual, Sharpe=1.36
#   Current Signal: NONE
#
# [109/503] Analyzing CFG ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0252, half-life=27.47 days
#   Strategy => 26.78% annual, Sharpe=1.65
#   Buy&Hold => 41.41% annual, Sharpe=1.17
#   Current Signal: LONG
#     Revert Price: 45.19
#     Time to 1/2 revert: 27.5 days (=> 2025-06-12)
#     Time to 90% revert: 91.3 days (=> 2025-08-15)
#     Expected % Return: 8.05%
#     Last Signal Date: 2025-05-16
#
# [110/503] Analyzing CLX ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0175, half-life=39.70 days
#   Strategy => 4.51% annual, Sharpe=0.30
#   Buy&Hold => -4.05% annual, Sharpe=-0.18
#   Current Signal: LONG
#     Revert Price: 146.80
#     Time to 1/2 revert: 39.7 days (=> 2025-06-24)
#     Time to 90% revert: 131.9 days (=> 2025-09-24)
#     Expected % Return: 7.72%
#     Last Signal Date: 2025-05-16
#
# [111/503] Analyzing CME ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0145, half-life=47.69 days
#   Strategy => 5.95% annual, Sharpe=0.67
#   Buy&Hold => 31.05% annual, Sharpe=1.75
#   Current Signal: SHORT
#     Revert Price: 253.59
#     Time to 1/2 revert: 47.7 days (=> 2025-07-02)
#     Time to 90% revert: 158.4 days (=> 2025-10-21)
#     Expected % Return: 8.22%
#     Last Signal Date: 2025-05-16
#
# [112/503] Analyzing CMS ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0306, half-life=22.62 days
#   Strategy => 15.11% annual, Sharpe=1.50
#   Buy&Hold => 16.08% annual, Sharpe=0.89
#   Current Signal: NONE
#
# [113/503] Analyzing KO ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0213, half-life=32.54 days
#   Strategy => 14.70% annual, Sharpe=1.74
#   Buy&Hold => 11.73% annual, Sharpe=0.77
#   Current Signal: SHORT
#     Revert Price: 69.30
#     Time to 1/2 revert: 32.5 days (=> 2025-06-17)
#     Time to 90% revert: 108.1 days (=> 2025-09-01)
#     Expected % Return: 3.75%
#     Last Signal Date: 2025-05-16
#
# [114/503] Analyzing CTSH ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0302, half-life=22.96 days
#   Strategy => 16.46% annual, Sharpe=1.57
#   Buy&Hold => 18.44% annual, Sharpe=0.81
#   Current Signal: NONE
#
# [115/503] Analyzing COIN ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0232, half-life=29.83 days
#   Strategy => 27.10% annual, Sharpe=0.57
#   Buy&Hold => 202.56% annual, Sharpe=2.46
#   Current Signal: NONE
#
# [116/503] Analyzing CL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0106, half-life=65.67 days
#   Strategy => 14.46% annual, Sharpe=1.35
#   Buy&Hold => 11.11% annual, Sharpe=0.63
#   Current Signal: LONG
#     Revert Price: 97.03
#     Time to 1/2 revert: 65.7 days (=> 2025-07-20)
#     Time to 90% revert: 218.2 days (=> 2025-12-20)
#     Expected % Return: 6.36%
#     Last Signal Date: 2025-05-16
#
# [117/503] Analyzing CMCSA ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0424, half-life=16.34 days
#   Strategy => 20.77% annual, Sharpe=1.86
#   Buy&Hold => -1.24% annual, Sharpe=-0.05
#   Current Signal: NONE
#
# [118/503] Analyzing CAG ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0227, half-life=30.47 days
#   Strategy => -1.67% annual, Sharpe=-0.16
#   Buy&Hold => -13.88% annual, Sharpe=-0.62
#   Current Signal: LONG
#     Revert Price: 25.39
#     Time to 1/2 revert: 30.5 days (=> 2025-06-15)
#     Time to 90% revert: 101.2 days (=> 2025-08-25)
#     Expected % Return: 10.48%
#     Last Signal Date: 2025-05-16
#
# [119/503] Analyzing COP ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0289, half-life=23.95 days
#   Strategy => 20.42% annual, Sharpe=1.73
#   Buy&Hold => 1.49% annual, Sharpe=0.05
#   Current Signal: LONG
#     Revert Price: 101.40
#     Time to 1/2 revert: 23.9 days (=> 2025-06-08)
#     Time to 90% revert: 79.6 days (=> 2025-08-03)
#     Expected % Return: 9.70%
#     Last Signal Date: 2025-05-16
#
# [120/503] Analyzing ED ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0287, half-life=24.12 days
#   Strategy => 7.86% annual, Sharpe=0.81
#   Buy&Hold => 10.42% annual, Sharpe=0.55
#   Current Signal: SHORT
#     Revert Price: 101.64
#     Time to 1/2 revert: 24.1 days (=> 2025-06-09)
#     Time to 90% revert: 80.1 days (=> 2025-08-04)
#     Expected % Return: 2.54%
#     Last Signal Date: 2025-05-16
#
# [121/503] Analyzing STZ ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0170, half-life=40.86 days
#   Strategy => -0.41% annual, Sharpe=-0.03
#   Buy&Hold => -4.49% annual, Sharpe=-0.19
#   Current Signal: LONG
#     Revert Price: 205.77
#     Time to 1/2 revert: 40.9 days (=> 2025-06-25)
#     Time to 90% revert: 135.7 days (=> 2025-09-28)
#     Expected % Return: 5.19%
#     Last Signal Date: 2025-05-16
#
# [122/503] Analyzing CEG ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0356, half-life=19.47 days
#   Strategy => 53.27% annual, Sharpe=2.06
#   Buy&Hold => 120.93% annual, Sharpe=2.19
#   Current Signal: NONE
#
# [123/503] Analyzing COO ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0158, half-life=43.95 days
#   Strategy => 21.10% annual, Sharpe=1.80
#   Buy&Hold => -4.14% annual, Sharpe=-0.16
#   Current Signal: LONG
#     Revert Price: 91.32
#     Time to 1/2 revert: 43.9 days (=> 2025-06-28)
#     Time to 90% revert: 146.0 days (=> 2025-10-08)
#     Expected % Return: 10.13%
#     Last Signal Date: 2025-05-16
#
# [124/503] Analyzing CPRT ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0338, half-life=20.51 days
#   Strategy => 21.15% annual, Sharpe=2.10
#   Buy&Hold => 23.46% annual, Sharpe=1.05
#   Current Signal: SHORT
#     Revert Price: 60.23
#     Time to 1/2 revert: 20.5 days (=> 2025-06-05)
#     Time to 90% revert: 68.1 days (=> 2025-07-23)
#     Expected % Return: 5.66%
#     Last Signal Date: 2025-05-16
#
# [125/503] Analyzing GLW ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0196, half-life=35.33 days
#   Strategy => 12.91% annual, Sharpe=0.85
#   Buy&Hold => 33.58% annual, Sharpe=1.17
#   Current Signal: NONE
#
# [126/503] Analyzing CPAY ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0305, half-life=22.75 days
#   Strategy => 17.03% annual, Sharpe=1.61
#   Buy&Hold => 27.84% annual, Sharpe=0.94
#   Current Signal: NONE
#
# [127/503] Analyzing CTVA ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0337, half-life=20.56 days
#   Strategy => 21.91% annual, Sharpe=1.21
#   Buy&Hold => 15.72% annual, Sharpe=0.55
#   Current Signal: SHORT
#     Revert Price: 61.26
#     Time to 1/2 revert: 20.6 days (=> 2025-06-05)
#     Time to 90% revert: 68.3 days (=> 2025-07-23)
#     Expected % Return: 10.71%
#     Last Signal Date: 2025-05-16
#
# [128/503] Analyzing CSGP ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0463, half-life=14.96 days
#   Strategy => 18.50% annual, Sharpe=1.48
#   Buy&Hold => 3.71% annual, Sharpe=0.12
#   Current Signal: NONE
#
# [129/503] Analyzing COST ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0342, half-life=20.28 days
#   Strategy => 9.60% annual, Sharpe=0.93
#   Buy&Hold => 49.72% annual, Sharpe=2.46
#   Current Signal: LONG
#     Revert Price: 1053.10
#     Time to 1/2 revert: 20.3 days (=> 2025-06-05)
#     Time to 90% revert: 67.4 days (=> 2025-07-22)
#     Expected % Return: 2.66%
#     Last Signal Date: 2025-05-16
#
# [130/503] Analyzing CTRA ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0351, half-life=19.77 days
#   Strategy => 13.61% annual, Sharpe=0.98
#   Buy&Hold => 5.30% annual, Sharpe=0.20
#   Current Signal: LONG
#     Revert Price: 25.95
#     Time to 1/2 revert: 19.8 days (=> 2025-06-04)
#     Time to 90% revert: 65.7 days (=> 2025-07-20)
#     Expected % Return: 4.62%
#     Last Signal Date: 2025-05-16
#
# [131/503] Analyzing CRWD ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0221, half-life=31.32 days
#   Strategy => 34.00% annual, Sharpe=1.33
#   Buy&Hold => 95.25% annual, Sharpe=2.03
#   Current Signal: SHORT
#     Revert Price: 417.49
#     Time to 1/2 revert: 31.3 days (=> 2025-06-16)
#     Time to 90% revert: 104.0 days (=> 2025-08-28)
#     Expected % Return: 4.96%
#     Last Signal Date: 2025-05-16
#
# [132/503] Analyzing CCI ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0219, half-life=31.60 days
#   Strategy => 11.56% annual, Sharpe=0.87
#   Buy&Hold => 4.46% annual, Sharpe=0.17
#   Current Signal: NONE
#
# [133/503] Analyzing CSX ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0193, half-life=35.98 days
#   Strategy => 19.44% annual, Sharpe=1.93
#   Buy&Hold => 2.30% annual, Sharpe=0.10
#   Current Signal: LONG
#     Revert Price: 32.57
#     Time to 1/2 revert: 36.0 days (=> 2025-06-20)
#     Time to 90% revert: 119.5 days (=> 2025-09-12)
#     Expected % Return: 3.99%
#     Last Signal Date: 2025-05-16
#
# [134/503] Analyzing CMI ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0192, half-life=36.07 days
#   Strategy => 11.77% annual, Sharpe=0.86
#   Buy&Hold => 31.94% annual, Sharpe=1.17
#   Current Signal: LONG
#     Revert Price: 352.63
#     Time to 1/2 revert: 36.1 days (=> 2025-06-21)
#     Time to 90% revert: 119.8 days (=> 2025-09-12)
#     Expected % Return: 5.43%
#     Last Signal Date: 2025-05-16
#
# [135/503] Analyzing CVS ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0208, half-life=33.29 days
#   Strategy => 23.41% annual, Sharpe=1.39
#   Buy&Hold => 4.96% annual, Sharpe=0.14
#   Current Signal: SHORT
#     Revert Price: 57.94
#     Time to 1/2 revert: 33.3 days (=> 2025-06-18)
# ...
#   OU => kappa=0.0293, half-life=23.63 days
#   Strategy => 2.70% annual, Sharpe=0.30
#   Buy&Hold => 13.06% annual, Sharpe=0.60
#   Current Signal: LONG
#     Revert Price: 244.26
#     Time to 1/2 revert: 23.6 days (=> 2025-06-08)
#     Time to 90% revert: 78.5 days (=> 2025-08-02)
#     Expected % Return: 5.55%
#     Last Signal Date: 2025-05-16
#
# [461/503] Analyzing UAL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0089, half-life=78.21 days
#   Strategy => 49.17% annual, Sharpe=2.14
#   Buy&Hold => 43.65% annual, Sharpe=0.91
#   Current Signal: NONE
#
# [462/503] Analyzing UPS ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0461, half-life=15.03 days
#   Strategy => 13.98% annual, Sharpe=1.50
#   Buy&Hold => -16.64% annual, Sharpe=-0.59
#   Current Signal: LONG
#     Revert Price: 108.65
#     Time to 1/2 revert: 15.0 days (=> 2025-05-31)
#     Time to 90% revert: 49.9 days (=> 2025-07-04)
#     Expected % Return: 7.23%
#     Last Signal Date: 2025-05-16
#
# [463/503] Analyzing URI ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0149, half-life=46.56 days
#   Strategy => 17.17% annual, Sharpe=0.77
#   Buy&Hold => 56.69% annual, Sharpe=1.50
#   Current Signal: LONG
#     Revert Price: 800.97
#     Time to 1/2 revert: 46.6 days (=> 2025-07-01)
#     Time to 90% revert: 154.7 days (=> 2025-10-17)
#     Expected % Return: 10.38%
#     Last Signal Date: 2025-05-16
#
# [464/503] Analyzing UNH ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0021, half-life=329.51 days
#   Strategy => 11.32% annual, Sharpe=0.50
#   Buy&Hold => -15.71% annual, Sharpe=-0.46
#   Current Signal: LONG
#     Revert Price: 329.63
#     Time to 1/2 revert: 329.5 days (=> 2026-04-10)
#     Time to 90% revert: 1094.6 days (=> 2028-05-14)
#     Expected % Return: 12.92%
#     Last Signal Date: 2025-05-16
#
# [465/503] Analyzing UHS ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0122, half-life=57.03 days
#   Strategy => 14.23% annual, Sharpe=0.79
#   Buy&Hold => 27.61% annual, Sharpe=0.93
#   Current Signal: LONG
#     Revert Price: 207.92
#     Time to 1/2 revert: 57.0 days (=> 2025-07-12)
#     Time to 90% revert: 189.4 days (=> 2025-11-21)
#     Expected % Return: 5.04%
#     Last Signal Date: 2025-05-16
#
# [466/503] Analyzing VLO ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0185, half-life=37.39 days
#   Strategy => 26.78% annual, Sharpe=1.56
#   Buy&Hold => 19.91% annual, Sharpe=0.61
#   Current Signal: LONG
#     Revert Price: 141.34
#     Time to 1/2 revert: 37.4 days (=> 2025-06-22)
#     Time to 90% revert: 124.2 days (=> 2025-09-17)
#     Expected % Return: 4.13%
#     Last Signal Date: 2025-05-16
#
# [467/503] Analyzing VTR ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0190, half-life=36.39 days
#   Strategy => 4.52% annual, Sharpe=0.38
#   Buy&Hold => 29.40% annual, Sharpe=1.21
#   Current Signal: NONE
#
# [468/503] Analyzing VLTO ...
#   Data Points: 411 from 2023-09-27 to 2025-05-16
#   OU => kappa=0.0133, half-life=52.31 days
#   Strategy => -0.71% annual, Sharpe=-0.06
#   Buy&Hold => 19.56% annual, Sharpe=0.77
#   Current Signal: LONG
#     Revert Price: 107.43
#     Time to 1/2 revert: 52.3 days (=> 2025-07-07)
#     Time to 90% revert: 173.8 days (=> 2025-11-05)
#     Expected % Return: 5.64%
#     Last Signal Date: 2025-05-16
#
# [469/503] Analyzing VRSN ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU Error => Estimated Phi=1.0009 out of (0,1). Not mean-reverting.
#
# [470/503] Analyzing VRSK ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0537, half-life=12.91 days
#   Strategy => 5.57% annual, Sharpe=1.14
#   Buy&Hold => 21.22% annual, Sharpe=1.09
#   Current Signal: SHORT
#     Revert Price: 296.12
#     Time to 1/2 revert: 12.9 days (=> 2025-05-28)
#     Time to 90% revert: 42.9 days (=> 2025-06-27)
#     Expected % Return: 4.35%
#     Last Signal Date: 2025-05-16
#
# [471/503] Analyzing VZ ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0437, half-life=15.87 days
#   Strategy => 15.78% annual, Sharpe=1.50
#   Buy&Hold => 21.63% annual, Sharpe=0.94
#   Current Signal: NONE
#
# [472/503] Analyzing VRTX ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0262, half-life=26.48 days
#   Strategy => 14.26% annual, Sharpe=1.03
#   Buy&Hold => 17.38% annual, Sharpe=0.66
#   Current Signal: LONG
#     Revert Price: 499.95
#     Time to 1/2 revert: 26.5 days (=> 2025-06-11)
#     Time to 90% revert: 88.0 days (=> 2025-08-11)
#     Expected % Return: 13.97%
#     Last Signal Date: 2025-05-16
#
# [473/503] Analyzing VTRS ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0114, half-life=60.61 days
#   Strategy => -2.64% annual, Sharpe=-0.14
#   Buy&Hold => 6.98% annual, Sharpe=0.22
#   Current Signal: LONG
#     Revert Price: 10.83
#     Time to 1/2 revert: 60.6 days (=> 2025-07-15)
#     Time to 90% revert: 201.3 days (=> 2025-12-03)
#     Expected % Return: 22.47%
#     Last Signal Date: 2025-05-16
#
# [474/503] Analyzing VICI ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0303, half-life=22.91 days
#   Strategy => 13.81% annual, Sharpe=1.29
#   Buy&Hold => 8.50% annual, Sharpe=0.44
#   Current Signal: SHORT
#     Revert Price: 31.21
#     Time to 1/2 revert: 22.9 days (=> 2025-06-07)
#     Time to 90% revert: 76.1 days (=> 2025-07-31)
#     Expected % Return: 2.77%
#     Last Signal Date: 2025-05-16
#
# [475/503] Analyzing V ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0255, half-life=27.13 days
#   Strategy => 12.31% annual, Sharpe=1.29
#   Buy&Hold => 28.44% annual, Sharpe=1.54
#   Current Signal: SHORT
#     Revert Price: 337.50
#     Time to 1/2 revert: 27.1 days (=> 2025-06-12)
#     Time to 90% revert: 90.1 days (=> 2025-08-14)
#     Expected % Return: 7.56%
#     Last Signal Date: 2025-05-16
#
# [476/503] Analyzing VST ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0332, half-life=20.87 days
#   Strategy => 48.09% annual, Sharpe=1.53
#   Buy&Hold => 206.96% annual, Sharpe=3.58
#   Current Signal: NONE
#
# [477/503] Analyzing VMC ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0230, half-life=30.10 days
#   Strategy => 25.96% annual, Sharpe=2.13
#   Buy&Hold => 22.75% annual, Sharpe=0.95
#   Current Signal: NONE
#
# [478/503] Analyzing WRB ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0370, half-life=18.73 days
#   Strategy => 11.78% annual, Sharpe=1.29
#   Buy&Hold => 45.17% annual, Sharpe=2.04
#   Current Signal: SHORT
#     Revert Price: 67.97
#     Time to 1/2 revert: 18.7 days (=> 2025-06-03)
#     Time to 90% revert: 62.2 days (=> 2025-07-17)
#     Expected % Return: 7.25%
#     Last Signal Date: 2025-05-16
#
# [479/503] Analyzing GWW ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0155, half-life=44.66 days
#   Strategy => 10.28% annual, Sharpe=0.95
#   Buy&Hold => 31.55% annual, Sharpe=1.44
#   Current Signal: LONG
#     Revert Price: 1130.25
#     Time to 1/2 revert: 44.7 days (=> 2025-06-29)
#     Time to 90% revert: 148.4 days (=> 2025-10-11)
#     Expected % Return: 2.59%
#     Last Signal Date: 2025-05-16
#
# [480/503] Analyzing WAB ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0244, half-life=28.35 days
#   Strategy => 14.36% annual, Sharpe=1.24
#   Buy&Hold => 51.07% annual, Sharpe=2.07
#   Current Signal: NONE
#
# [481/503] Analyzing WBA ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0135, half-life=51.22 days
#   Strategy => -0.20% annual, Sharpe=-0.01
#   Buy&Hold => -27.48% annual, Sharpe=-0.53
#   Current Signal: SHORT
#     Revert Price: 6.88
#     Time to 1/2 revert: 51.2 days (=> 2025-07-06)
#     Time to 90% revert: 170.1 days (=> 2025-11-02)
#     Expected % Return: 39.10%
#     Last Signal Date: 2025-05-16
#
# [482/503] Analyzing WMT ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0191, half-life=36.27 days
#   Strategy => 3.48% annual, Sharpe=0.29
#   Buy&Hold => 45.21% annual, Sharpe=2.18
#   Current Signal: SHORT
#     Revert Price: 95.61
#     Time to 1/2 revert: 36.3 days (=> 2025-06-21)
#     Time to 90% revert: 120.5 days (=> 2025-09-13)
#     Expected % Return: 2.68%
#     Last Signal Date: 2025-05-16
#
# [483/503] Analyzing DIS ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0160, half-life=43.19 days
#   Strategy => 31.38% annual, Sharpe=2.09
#   Buy&Hold => 16.87% annual, Sharpe=0.59
#   Current Signal: SHORT
#     Revert Price: 107.06
#     Time to 1/2 revert: 43.2 days (=> 2025-06-28)
#     Time to 90% revert: 143.5 days (=> 2025-10-06)
#     Expected % Return: 5.61%
#     Last Signal Date: 2025-05-16
#
# [484/503] Analyzing WBD ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0255, half-life=27.14 days
#   Strategy => 24.46% annual, Sharpe=0.81
#   Buy&Hold => 0.17% annual, Sharpe=0.00
#   Current Signal: SHORT
#     Revert Price: 8.21
#     Time to 1/2 revert: 27.1 days (=> 2025-06-12)
#     Time to 90% revert: 90.2 days (=> 2025-08-14)
#     Expected % Return: 10.37%
#     Last Signal Date: 2025-05-16
#
# [485/503] Analyzing WM ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0283, half-life=24.45 days
#   Strategy => 7.51% annual, Sharpe=0.93
#   Buy&Hold => 21.87% annual, Sharpe=1.21
#   Current Signal: LONG
#     Revert Price: 234.67
#     Time to 1/2 revert: 24.5 days (=> 2025-06-09)
#     Time to 90% revert: 81.2 days (=> 2025-08-05)
#     Expected % Return: 2.09%
#     Last Signal Date: 2025-05-16
#
# [486/503] Analyzing WAT ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0398, half-life=17.40 days
#   Strategy => 21.95% annual, Sharpe=1.45
#   Buy&Hold => 22.81% annual, Sharpe=0.67
#   Current Signal: LONG
#     Revert Price: 382.69
#     Time to 1/2 revert: 17.4 days (=> 2025-06-02)
#     Time to 90% revert: 57.8 days (=> 2025-07-12)
#     Expected % Return: 6.46%
#     Last Signal Date: 2025-05-16
#
# [487/503] Analyzing WEC ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0153, half-life=45.16 days
#   Strategy => 9.45% annual, Sharpe=0.93
#   Buy&Hold => 14.98% annual, Sharpe=0.82
#   Current Signal: SHORT
#     Revert Price: 99.71
#     Time to 1/2 revert: 45.2 days (=> 2025-06-30)
#     Time to 90% revert: 150.0 days (=> 2025-10-13)
#     Expected % Return: 6.35%
#     Last Signal Date: 2025-05-16
#
# [488/503] Analyzing WFC ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0267, half-life=26.01 days
#   Strategy => 32.00% annual, Sharpe=2.35
#   Buy&Hold => 47.97% annual, Sharpe=1.67
#   Current Signal: NONE
#
# [489/503] Analyzing WELL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0259, half-life=26.80 days
#   Strategy => 2.01% annual, Sharpe=0.17
#   Buy&Hold => 46.30% annual, Sharpe=2.19
#   Current Signal: NONE
#
# [490/503] Analyzing WST ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0384, half-life=18.04 days
#   Strategy => 37.71% annual, Sharpe=1.19
#   Buy&Hold => -12.16% annual, Sharpe=-0.27
#   Current Signal: LONG
#     Revert Price: 258.80
#     Time to 1/2 revert: 18.0 days (=> 2025-06-03)
#     Time to 90% revert: 59.9 days (=> 2025-07-14)
#     Expected % Return: 19.46%
#     Last Signal Date: 2025-05-16
#
# [491/503] Analyzing WDC ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0140, half-life=49.51 days
#   Strategy => 36.07% annual, Sharpe=1.71
#   Buy&Hold => 44.08% annual, Sharpe=1.04
#   Current Signal: LONG
#     Revert Price: 53.69
#     Time to 1/2 revert: 49.5 days (=> 2025-07-04)
#     Time to 90% revert: 164.5 days (=> 2025-10-27)
#     Expected % Return: 7.40%
#     Last Signal Date: 2025-05-16
#
# [492/503] Analyzing WY ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0274, half-life=25.28 days
#   Strategy => 23.57% annual, Sharpe=1.87
#   Buy&Hold => 0.52% annual, Sharpe=0.02
#   Current Signal: LONG
#     Revert Price: 29.29
#     Time to 1/2 revert: 25.3 days (=> 2025-06-10)
#     Time to 90% revert: 84.0 days (=> 2025-08-07)
#     Expected % Return: 9.60%
#     Last Signal Date: 2025-05-16
#
# [493/503] Analyzing WSM ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0234, half-life=29.62 days
#   Strategy => 18.41% annual, Sharpe=0.70
#   Buy&Hold => 99.17% annual, Sharpe=2.06
#   Current Signal: LONG
#     Revert Price: 193.07
#     Time to 1/2 revert: 29.6 days (=> 2025-06-14)
#     Time to 90% revert: 98.4 days (=> 2025-08-22)
#     Expected % Return: 11.06%
#     Last Signal Date: 2025-05-16
#
# [494/503] Analyzing WMB ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0278, half-life=24.96 days
#   Strategy => 14.26% annual, Sharpe=1.13
#   Buy&Hold => 52.74% annual, Sharpe=2.37
#   Current Signal: NONE
#
# [495/503] Analyzing WTW ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0364, half-life=19.03 days
#   Strategy => 3.87% annual, Sharpe=0.43
#   Buy&Hold => 20.88% annual, Sharpe=0.99
#   Current Signal: LONG
#     Revert Price: 329.47
#     Time to 1/2 revert: 19.0 days (=> 2025-06-04)
#     Time to 90% revert: 63.2 days (=> 2025-07-18)
#     Expected % Return: 5.62%
#     Last Signal Date: 2025-05-16
#
# [496/503] Analyzing WDAY ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0263, half-life=26.31 days
#   Strategy => 29.13% annual, Sharpe=2.09
#   Buy&Hold => 25.11% annual, Sharpe=0.75
#   Current Signal: SHORT
#     Revert Price: 260.82
#     Time to 1/2 revert: 26.3 days (=> 2025-06-11)
#     Time to 90% revert: 87.4 days (=> 2025-08-11)
#     Expected % Return: 4.48%
#     Last Signal Date: 2025-05-16
#
# [497/503] Analyzing WYNN ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0328, half-life=21.12 days
#   Strategy => 32.27% annual, Sharpe=1.88
#   Buy&Hold => 0.66% annual, Sharpe=0.02
#   Current Signal: SHORT
#     Revert Price: 83.12
#     Time to 1/2 revert: 21.1 days (=> 2025-06-06)
#     Time to 90% revert: 70.1 days (=> 2025-07-25)
#     Expected % Return: 14.10%
#     Last Signal Date: 2025-05-16
#
# [498/503] Analyzing XEL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0179, half-life=38.67 days
#   Strategy => 11.37% annual, Sharpe=0.96
#   Buy&Hold => 10.74% annual, Sharpe=0.50
#   Current Signal: SHORT
#     Revert Price: 66.66
#     Time to 1/2 revert: 38.7 days (=> 2025-06-23)
#     Time to 90% revert: 128.5 days (=> 2025-09-21)
#     Expected % Return: 7.91%
#     Last Signal Date: 2025-05-16
#
# [499/503] Analyzing XYL ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0106, half-life=65.12 days
#   Strategy => 14.61% annual, Sharpe=1.13
#   Buy&Hold => 14.83% annual, Sharpe=0.65
#   Current Signal: LONG
#     Revert Price: 132.43
#     Time to 1/2 revert: 65.1 days (=> 2025-07-20)
#     Time to 90% revert: 216.3 days (=> 2025-12-18)
#     Expected % Return: 3.44%
#     Last Signal Date: 2025-05-16
#
# [500/503] Analyzing YUM ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0331, half-life=20.93 days
#   Strategy => 11.09% annual, Sharpe=1.06
#   Buy&Hold => 7.52% annual, Sharpe=0.39
#   Current Signal: SHORT
#     Revert Price: 143.06
#     Time to 1/2 revert: 20.9 days (=> 2025-06-05)
#     Time to 90% revert: 69.5 days (=> 2025-07-24)
#     Expected % Return: 3.38%
#     Last Signal Date: 2025-05-16
#
# [501/503] Analyzing ZBRA ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0113, half-life=61.49 days
#   Strategy => 30.57% annual, Sharpe=1.32
#   Buy&Hold => 12.34% annual, Sharpe=0.31
#   Current Signal: LONG
#     Revert Price: 336.75
#     Time to 1/2 revert: 61.5 days (=> 2025-07-16)
#     Time to 90% revert: 204.3 days (=> 2025-12-06)
#     Expected % Return: 11.97%
#     Last Signal Date: 2025-05-16
#
# [502/503] Analyzing ZBH ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0256, half-life=27.07 days
#   Strategy => 21.79% annual, Sharpe=1.62
#   Buy&Hold => -12.15% annual, Sharpe=-0.51
#   Current Signal: NONE
#
# [503/503] Analyzing ZTS ...
#   Data Points: 500 from 2023-05-19 to 2025-05-16
#   OU => kappa=0.0307, half-life=22.60 days
#   Strategy => 7.17% annual, Sharpe=0.55
#   Buy&Hold => -0.28% annual, Sharpe=-0.01
#   Current Signal: NONE
#
# Done. Results saved to '/workspaces/Stock-Market-Prediction/Quantative Investment/QI Output/Reversion/2025-05-18/sp500_mr_momentum_results_with_signal.csv'.
